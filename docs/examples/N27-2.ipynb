# %% [markdown]
# # Example N27-2
#
# Get an overview of levee charcateristics for levee trajectory 27-2.
#
# Thanks to package `GeoProfile` that allows to visualise geotechnical data in Python.

# %%
import os
import pickle
import pandas as pd
import numpy as np

import datetime

import logging
logging.basicConfig(level=logging.DEBUG)
# when logging level = DEBUG, skip messages from matplotlib and PIL
for lib in ['rasterio', 'matplotlib', 'PIL', 'urllib3', 'choreographer', 'kaleido']:
    logging.getLogger(lib).setLevel(logging.INFO)

# %%
import hydropandas as hpd
hpd.__version__
# Out:
# '0.18.0'

# %%
import geoprofile
geoprofile.__version__
# Out:
# '0.4.0'

# %%
# TODO: De functies van `geolookup` staan nu allemaal in een .py bestand. Dit nog Python-ic maken. Met een init.py en verschillende sub besatanden

# %%
import sys
sys.path.append(r'..\..\geolookup')

import functions as gl

# %% [markdown]
# # Gegevens openen

# %%
DATA_PATH = r'N27-2_data\\'
PLOT_PATH = r'N27-2_plots\\'

# %% [markdown]
# ## CPTs
#
# Downloaded from Broloket and classified via `CPTcore` using Robertson classification.

# %%
# TODO: change method to plot CPTs in section perpendicular to levee. Now data is projected using Waterschap Scheldestromen method to
# project CPTs relative to reference line (x=0). Therefore, preprocessing is done outside this repo.

# %%
region = 'Os'
dp_min = 725
dp_max = 1080
cpt_classification = 'Robertson'

fn = DATA_PATH + f'geoprofile_columns_robertson_{region}_dp{dp_min}-{dp_max}.pkl'
logging.info(f"File last modified: {datetime.datetime.fromtimestamp(os.path.getmtime(fn)) - datetime.datetime.now()}")
with open(fn, "rb") as f:
    geoprofile_cols = pickle.load(f)
gl.describe_columns(geoprofile_cols)
# Out:
# INFO:root:File last modified: -5 days, 2:18:08.754255
# INFO:root:Number of columns: 1248
# INFO:root:Dike pole range: dp726.6 - dp1081.5, total 759 unique dike poles.
# INFO:root:Data X: centered at 64380 with span 13 km, Y: centered at 397930 with span 11 km

# %% [markdown]
# ## Hectometer indicator

# %%
df_hm = pd.read_csv(DATA_PATH + f'table_dijkpalen_{region}_dp{dp_min}-{dp_max}.csv')
df_hm.dp.describe()
# Out:
# count     711.000000
# mean      902.500000
# std       102.696154
# min       725.000000
# 25%       813.750000
# 50%       902.500000
# 75%       991.250000
# max      1080.000000
# Name: dp, dtype: float64

# %% [markdown]
# ## Schematised levee profiles

# %%
df_profiles = pd.read_csv(DATA_PATH + f'table_profielen_{region}_dp{dp_min}-{dp_max}.csv')
df_profiles.head()
# Out:
#   region     dp  ymv.bui  ysloot.1d  xmv.bin  xsloot.1a  xsloot.1c  xsloot.1d  \
# 0     Os  725.0   -0.253       -0.5   -91.13     -52.13     -50.79     -50.39
# 1     Os  726.0   -0.583        0.0  -200.88     -97.88     -95.77     -92.82
# 2     Os  727.0   -0.928        0.5   -51.22     -23.22     -21.81     -20.57
# 3     Os  728.0   -0.926        0.5  -201.00     -24.00     -22.64     -22.60
# 4     Os  729.0   -1.034        0.5  -201.00     -23.62     -22.34     -20.45
#
#    xsloot.1b  xweg.1  ...  yteen.1  yberm.1a  yberm.1b  ykruin.1  ykruin.2  \
# 0     -49.13  -25.13  ...     1.71      6.26      6.39      6.39      6.22
# 1     -90.88  -18.88  ...     2.45      6.43      6.43      6.43      6.41
# 2     -19.22  -19.22  ...     2.08      6.51      6.51      6.51      6.43
# 3     -21.00  -21.00  ...     1.86      6.45      6.45      6.45      6.37
# 4     -19.00  -19.00  ...     1.50      6.46      6.46      6.46      6.42
#
#    yberm.2a  yberm.2b  yteen.2  yweg.2  ysloot.2
# 0      4.63      4.33     0.03   0.773    -0.071
# 1      4.58      4.28     0.05  -0.700    -0.640
# 2      4.53      4.27    -0.74  -0.776    -0.776
# 3      4.44      4.23     0.26  -0.130    -0.929
# 4      4.48      4.25    -0.76  -1.046    -0.936
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Section profiles
#
# Distance along trajectory where drawing (section profile) is available.

# %%
df_section = pd.read_csv(DATA_PATH + f'table_deltaversterking_{region}_dp{dp_min}-{dp_max}.csv')
df_section['description'] = 'Deltaversterking'
df_section.dsn_file_tif = DATA_PATH + df_section.dsn_file_tif 
df_section.head()
# Out:
#   region     dp                                       dsn_file_tif  \
# 0     Os  725.5  N27-2_data\\deltaversterking\os0725-0778\doors...
# 1     Os  730.5  N27-2_data\\deltaversterking\os0725-0778\doors...
# 2     Os  734.5  N27-2_data\\deltaversterking\os0725-0778\doors...
# 3     Os  736.5  N27-2_data\\deltaversterking\os0725-0778\doors...
# 4     Os  744.9  N27-2_data\\deltaversterking\os0725-0778\doors...
#
#         description
# 0  Deltaversterking
# 1  Deltaversterking
# 2  Deltaversterking
# 3  Deltaversterking
# 4  Deltaversterking

# %% [markdown]
# ## Groundwater monitoring and time series
# Using `HydroPandas`

# %%
#TODO: functie maken die ouderom netjes aangeeft, als > dag, in dagen, anders in uren, anders in minuten
fn = DATA_PATH + f'oc_gwl_{region}_dp{dp_min}-{dp_max}.pkl'
oc_gwl = hpd.read_pickle(fn)
logging.info(f"File last modified: {(datetime.datetime.fromtimestamp(os.path.getmtime(fn)) - datetime.datetime.now()).total_seconds() / 60:.2f} minutes")
gl.describe_oc(oc_gwl, expected_obs_interval=10)
# Out:
# INFO:root:File last modified: -7106.03 minutes
# INFO:root:Obs Collection has 85 monitoring wells, on 66 locations. First observation 2007-08-29, last observation 2025-11-22
# INFO:root:Obs Collection has on average 1.1 years of observations per monitoring well, median 1.3 years. Assuming observations interval each 10 minutes.
# INFO:root:Data X: centered at 64220 with span 13 km, Y: centered at 397920 with span 10 km
# INFO:root:Index is unique.

# %%
# not all standpipes are in Broloket at the moment (work in progess, I know)
# standpipes that are in Broloket are downloaded, distances along and perpendicular to levee added
df_gmws = pd.read_csv(DATA_PATH + 'gmws_met_dp_en_afstanden.csv', index_col=0)
print("Is index unique?", df_gmws.index.is_unique)
df_gmws.head()
# Out:
# Is index unique? True
#                              broId  tubeNumber constructionStandard  \
# bro_identifier
# GMW000000064173-1  GMW000000064173           1              NEN5104
# GMW000000064174-1  GMW000000064174           1              NEN5104
# GMW000000064635-1  GMW000000064635           1              NEN5104
# GMW000000064641-1  GMW000000064641           1              NEN5104
# GMW000000082197-1  GMW000000082197           1              NEN5104
#
#                   coordinateTransformation corrected  \
# bro_identifier
# GMW000000064173-1           RDNAPTRANS2018       nee
# GMW000000064174-1           RDNAPTRANS2018       nee
# GMW000000064635-1           RDNAPTRANS2018       nee
# GMW000000064641-1           RDNAPTRANS2018       nee
# GMW000000082197-1           RDNAPTRANS2018       nee
#
#                               deliveredLocation  deliveryAccountableParty  \
# bro_identifier
# GMW000000064173-1  POINT (66087.627 402728.068)                  51640813
# GMW000000064174-1  POINT (66063.802 402740.143)                  51640813
# GMW000000064635-1  POINT (70954.224 392370.279)                  51640813
# GMW000000064641-1  POINT (70959.858 392366.996)                  51640813
# GMW000000082197-1  POINT (51425.398 406745.471)                  51640813
#
#                   deliveryContext deregistered  groundLevelPosition  ...  \
# bro_identifier                                                       ...
# GMW000000064173-1    publiekeTaak          nee                0.485  ...
# GMW000000064174-1    publiekeTaak          nee                0.552  ...
# GMW000000064635-1    publiekeTaak          nee                3.112  ...
# GMW000000064641-1    publiekeTaak          nee                4.737  ...
# GMW000000082197-1              WW          nee                9.270  ...
#
#                   screenBottomPosition plainTubePartLength sedimentSumpLength  \
# bro_identifier
# GMW000000064173-1               -1.315                0.70                NaN
# GMW000000064174-1               -1.448                0.88                NaN
# GMW000000064635-1               -0.888                2.95                1.0
# GMW000000064641-1               -2.263                5.95                1.0
# GMW000000082197-1              -14.731               22.87                1.0
#
#                            x           y                      geometry  \
# bro_identifier
# GMW000000064173-1  66087.627  402728.068  POINT (66087.627 402728.068)
# GMW000000064174-1  66063.802  402740.143  POINT (66063.802 402740.143)
# GMW000000064635-1  70954.224  392370.279  POINT (70954.224 392370.279)
# GMW000000064641-1  70959.858  392366.996  POINT (70959.858 392366.996)
# GMW000000082197-1  51425.398  406745.471  POINT (51425.398 406745.471)
#
#                    ref_distance       dp  distance_to_ref  region
# bro_identifier
# GMW000000064173-1       78437.0   784.37       -30.560607      Os
# GMW000000064174-1       78443.0   784.43       -56.800483      Os
# GMW000000064635-1      108150.0  1081.50        16.003035      Os
# GMW000000064641-1      108151.0  1081.51         9.511578      Os
# GMW000000082197-1       18001.0   180.01        -1.756535      Os
#
# [5 rows x 59 columns]

# %% [markdown]
# # Section along the trajectory of the levee
#
# Using the standard `profile` function of `GeoProfile`. It is called within a specific `GeoLookup` function, that creates the path.
# Afterwards levee charecteristics are added to the plot. That uses the `dp` (hectometer) property of these data sets.
#
# Section opens in a browser window. Map is included below.

# %%
if 0:
    region = 'Os'
    dp_list = [818, 821]
    dp_list = np.arange(818, 821+1)
    #dp_list = [930, 936]
    fig, profile = gl.plot_geoprofile(
        geoprofile_cols, 
        df_hm, 
        dp_list,
        oc_gwl=oc_gwl, 
        buffer=60, 
        projectname=f"Along levee {region} {min(dp_list)}-{max(dp_list)} {cpt_classification}",
        title_suffix='',
        plot_path=PLOT_PATH,)

# %%
# TODO: plotting of standpipes via oc_gwl is not working visible in maps. Annotation is plotted, legend as well. Standpipe itself not visible.

# %% [markdown]
# # Doorsnede maken bij dijkpaal
#
# Een doorsnede haaks op de dijk, ter hoogte van een dijkpaal. Weergegeven wordt het beschikbare grondonderzoek, de dichtstbijzijnde versterkingstekening van de Deltaversterking, het actuele maaiveld profiel en de peilbuizen.
#
# Informatie van meerdere dijkpalen wordt weergegeven wanneer de `delta_dp` variabele wort gebuikt. Informatie van lagere dijkpalen krijgt een rode tint, informatie van hogere dijkpalen een blauwe.
#
# Grondonderzoek wordt geprojecteerd ten opzichte van de referentielijn. Het wordt nooit bovenopelkaargeplot. Dan krijgt het een offset. Die offset is weergegeven tussen de haakjes in het label. Grondonderzoek van de opgevraagde raai wordt als eerste geplot, en staat dus vrijwel altijd op de juiste plek.

# %%
dp_center = 820
delta_dp = 1

df_gmws['position'] = 'broloket'
df_gmws = df_gmws.rename(columns={'screenTopPosition': 'screen_top',
                        'screenBottomPosition': 'screen_bottom',})

df_plot = df_gmws.loc[df_gmws.dp.between(
            dp_center - delta_dp, dp_center + delta_dp) & (df_gmws.region == region)].copy()

# Extract the number of zeros after the first three characters (e.g., after 'GMW')
min_padding_zeros = (
    df_plot.index.str[3:]
    .str.extract(r'^(0+)')[0]
    .str.len()
    .min()
)
print("Minimum number of padding zeros in index:", min_padding_zeros)

df_plot['label'] = df_plot.index.str.replace(
    r'^(GMW)(0{%d})' % min_padding_zeros, r'\1', regex=True
)


gl.create_figure_for_dp(
    dp_center, 
    df_section, 
    geoprofile_cols, 
    df_profiles,
    oc_gwl,
    df_gmws=df_plot,
    delta_dp=delta_dp,
    plot_gwl=True,
    plot_path=PLOT_PATH,
    ylims_upper=[-4, 7]
    )
# Out:
# DEBUG:root:Closest dp with Deltaversterking to 820 is 818.1, fn: es\dsn10_flipped.tif
# Minimum number of padding zeros in index: 7
# DEBUG:root:Adding Deltaversterking background from 9\doorsnedes\dsn10_flipped.tif to figure at row 1, col 1.
# DEBUG:root:Plotting column dp 820.0, distance=-2.763735125639539, plotted=[np.float64(-3.0)]
# DEBUG:root:Plotting column dp 820.0, distance=-14.7556743357624, plotted=[np.float64(-3.0), np.float64(-15.0)]
# DEBUG:root:Plotting column dp 819.5, distance=-15.441061606105023, plotted=[np.float64(-3.0), np.float64(-15.0), np.float64(-16.0)]
# DEBUG:root:Plotting column dp 820.5, distance=-17.26704174450618, plotted=[np.float64(-3.0), np.float64(-15.0), np.float64(-16.0), np.float64(-17.0)]
# DEBUG:root:Plotting column dp 819.0, distance=-2.161589776560799, plotted=[np.float64(-3.0), np.float64(-15.0), np.float64(-16.0), np.float64(-17.0), np.float64(-2.0)]
# DEBUG:root:Plotting column dp 819.0, distance=-19.641947163776827, plotted=[np.float64(-3.0), np.float64(-15.0), np.float64(-16.0), np.float64(-17.0), np.float64(-2.0), np.float64(-20.0)]
# DEBUG:root:Plotting column dp 821.0, distance=-19.62964556333043, plotted=[np.float64(-3.0), np.float64(-15.0), np.float64(-16.0), np.float64(-17.0), np.float64(-2.0), np.float64(-20.0), np.float64(-19.0)]
# DEBUG:root:Plotting column dp 821.0, distance=-1.6404331836623527, plotted=[np.float64(-3.0), np.float64(-15.0), np.float64(-16.0), np.float64(-17.0), np.float64(-2.0), np.float64(-20.0), np.float64(-19.0), np.float64(-1.0)]
# DEBUG:root:Closest dp with surface level profile to 820 is 820.0
# INFO:root:Plotting 2 standpipes in figure, method=by_dp.
# DEBUG:root:length oc: 2
# DEBUG:root:oc position values: ['kruin']
# DEBUG:root:GMWs worden geplot, aantal: 4
# INFO:root:Plotting 4 standpipes in figure, method=by_dp.
# DEBUG:root:length oc: 4
# DEBUG:root:oc position values: ['broloket']
# DEBUG:asyncio:Using selector: SelectSelector
# INFO:choreographer.browsers.chromium:Chromium init'ed with kwargs {}
# DEBUG:root:Looking for browser, skipping local? False
# DEBUG:root:Looking for at local chrome download path: C:\Users\HMEUW\.conda\envs\wk20260129\Lib\site-packages\choreographer\cli\browser_exe\chrome-win64\chrome.exe
# DEBUG:root:Local chrome not found at path: C:\Users\HMEUW\.conda\envs\wk20260129\Lib\site-packages\choreographer\cli\browser_exe\chrome-win64\chrome.exe.
# INFO:choreographer.browsers.chromium:Found chromium path: C:\Program Files\Google\Chrome\Application\chrome.exe
# INFO:choreographer.utils._tmpfile:Temp directory created: C:\Users\HMEUW\AppData\Local\Temp\tmp8qjq2xxx.
# INFO:choreographer.browser_async:Opening browser.
# INFO:choreographer.utils._tmpfile:Temp directory created: C:\Users\HMEUW\AppData\Local\Temp\tmp0suj443w.
# INFO:choreographer.browsers.chromium:Temporary directory at: C:\Users\HMEUW\AppData\Local\Temp\tmp0suj443w
# DEBUG:browser_proc:[INFO:components\enterprise\browser\controller\chrome_browser_cloud_management_controller.cc:206] No machine level policy manager exists.
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\external_pref_loader.cc:296] You are using an old-style extension deployment method (external_extensions.json), which will soon be deprecated. (see http://developer.chrome.com/docs/extensions/how-to/distribute/install-extensions)
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\external_registry_loader_win.cc:236] Error observing HKLM: Toegang geweigerd. (0x5)
# INFO:kaleido.kaleido:Conforming 1 to file:///C:/Users/HMEUW/AppData/Local/Temp/tmp8qjq2xxx/index.html
# INFO:kaleido.kaleido:Waiting on all navigates
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\forced_extensions\force_installed_metrics.cc:511] All forced extensions seem to be installed
# INFO:kaleido.kaleido:All navigates done, putting them all in queue.
# INFO:kaleido.kaleido:Getting tab from queue (has 1)
# INFO:kaleido.kaleido:Got D60B
# INFO:kaleido._kaleido_tab:Processing profiel_rondom_dp820__100m_tekening_Deltaversterking_bij_dp8181__190m.png
# INFO:kaleido._kaleido_tab:Sending big command for profiel_rondom_dp820__100m_tekening_Deltaversterking_bij_dp8181__190m.png.
# INFO:kaleido._kaleido_tab:Sent big command for profiel_rondom_dp820__100m_tekening_Deltaversterking_bij_dp8181__190m.png.
# INFO:kaleido.kaleido:Reloading tab D60B before return.
# INFO:kaleido.kaleido:Putting tab D60B back (queue size: 0).
# INFO:kaleido.kaleido:Waiting for all cleanups to finish.
# INFO:kaleido.kaleido:Exiting Kaleido
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# (Figure({
#      'data': [{'fill': 'toself',
#                'fillcolor': '#008000',
#                'fillpattern': {'shape': '/'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('klei'),
#                'line': {'color': '#008000'},
#                'mode': 'lines',
#                'name': np.str_('klei'),
#                'showlegend': True,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'layer: 5.14<br>Thickness: 0.52'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [5.657, 5.1370000000000005, 5.1370000000000005, 5.657, 5.657],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#008000',
#                'fillpattern': {'shape': '/'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('klei'),
#                'line': {'color': '#008000'},
#                'mode': 'lines',
#                'name': np.str_('klei'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'layer: 1.06<br>Thickness: 0.74'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [1.7970000000000006, 1.0570000000000004, 1.0570000000000004,
#                      1.7970000000000006, 1.7970000000000006],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#008000',
#                'fillpattern': {'shape': '/'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('klei'),
#                'line': {'color': '#008000'},
#                'mode': 'lines',
#                'name': np.str_('klei'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'layer: 0.44<br>Thickness: 0.16'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [0.5970000000000004, 0.4370000000000003, 0.4370000000000003,
#                      0.5970000000000004, 0.5970000000000004],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#008000',
#                'fillpattern': {'shape': '/'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('klei'),
#                'line': {'color': '#008000'},
#                'mode': 'lines',
#                'name': np.str_('klei'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'ayer: -0.20<br>Thickness: 0.04'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [-0.16300000000000026, -0.2029999999999994,
#                      -0.2029999999999994, -0.16300000000000026,
#                      -0.16300000000000026],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#008000',
#                'fillpattern': {'shape': '/'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('klei'),
#                'line': {'color': '#008000'},
#                'mode': 'lines',
#                'name': np.str_('klei'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'ayer: -0.28<br>Thickness: 0.04'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [-0.24299999999999944, -0.2829999999999995,
#                      -0.2829999999999995, -0.24299999999999944,
#                      -0.24299999999999944],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#008000',
#                'fillpattern': {'shape': '/'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('klei'),
#                'line': {'color': '#008000'},
#                'mode': 'lines',
#                'name': np.str_('klei'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'ayer: -3.44<br>Thickness: 2.50'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [-0.9429999999999996, -3.4429999999999996, -3.4429999999999996,
#                      -0.9429999999999996, -0.9429999999999996],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#008000',
#                'fillpattern': {'shape': '/'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('klei'),
#                'line': {'color': '#008000'},
#                'mode': 'lines',
#                'name': np.str_('klei'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'ayer: -9.18<br>Thickness: 5.44'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [-3.7430000000000003, -9.183, -9.183, -3.7430000000000003,
#                      -3.7430000000000003],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#008000',
#                'fillpattern': {'shape': '/'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('klei'),
#                'line': {'color': '#008000'},
#                'mode': 'lines',
#                'name': np.str_('klei'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -11.10<br>Thickness: 1.68'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [-9.423, -11.103000000000002, -11.103000000000002, -9.423,
#                      -9.423],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#008000',
#                'fillpattern': {'shape': '/'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('klei'),
#                'line': {'color': '#008000'},
#                'mode': 'lines',
#                'name': np.str_('klei'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -12.58<br>Thickness: 0.20'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [-12.383, -12.582999999999998, -12.582999999999998, -12.383,
#                      -12.383],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#008000',
#                'fillpattern': {'shape': '/'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('klei'),
#                'line': {'color': '#008000'},
#                'mode': 'lines',
#                'name': np.str_('klei'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -13.06<br>Thickness: 0.20'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [-12.863, -13.062999999999999, -13.062999999999999, -12.863,
#                      -12.863],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#008000',
#                'fillpattern': {'shape': '/'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('klei'),
#                'line': {'color': '#008000'},
#                'mode': 'lines',
#                'name': np.str_('klei'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -17.94<br>Thickness: 0.04'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [-17.903, -17.943, -17.943, -17.903, -17.903],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#808080',
#                'fillpattern': {'shape': '|'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('sterkZandigSilt'),
#                'line': {'color': '#808080'},
#                'mode': 'lines',
#                'name': np.str_('sterkZandigSilt'),
#                'showlegend': True,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'layer: 1.80<br>Thickness: 0.12'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.7, -2.7, -3.4],
#                'xaxis': 'x',
#                'y': [1.9170000000000003, 1.7970000000000006, 1.7970000000000006,
#                      1.9170000000000003, 1.9170000000000003],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('sterkZandigSilt'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('sterkZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'layer: 1.80<br>Thickness: 0.12'),
#                'type': 'scatter',
#                'x': [-2.7, -2.7, -2.4000000000000004, -2.4000000000000004, -2.7],
#                'xaxis': 'x',
#                'y': [1.9170000000000003, 1.7970000000000006, 1.7970000000000006,
#                      1.9170000000000003, 1.9170000000000003],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#808080',
#                'fillpattern': {'shape': '|'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('sterkZandigSilt'),
#                'line': {'color': '#808080'},
#                'mode': 'lines',
#                'name': np.str_('sterkZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'layer: 0.26<br>Thickness: 0.18'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.7, -2.7, -3.4],
#                'xaxis': 'x',
#                'y': [0.4370000000000003, 0.25700000000000056, 0.25700000000000056,
#                      0.4370000000000003, 0.4370000000000003],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('sterkZandigSilt'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('sterkZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'layer: 0.26<br>Thickness: 0.18'),
#                'type': 'scatter',
#                'x': [-2.7, -2.7, -2.4000000000000004, -2.4000000000000004, -2.7],
#                'xaxis': 'x',
#                'y': [0.4370000000000003, 0.25700000000000056, 0.25700000000000056,
#                      0.4370000000000003, 0.4370000000000003],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#808080',
#                'fillpattern': {'shape': '|'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('sterkZandigSilt'),
#                'line': {'color': '#808080'},
#                'mode': 'lines',
#                'name': np.str_('sterkZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -11.38<br>Thickness: 0.18'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.7, -2.7, -3.4],
#                'xaxis': 'x',
#                'y': [-11.203, -11.383, -11.383, -11.203, -11.203],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('sterkZandigSilt'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('sterkZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -11.38<br>Thickness: 0.18'),
#                'type': 'scatter',
#                'x': [-2.7, -2.7, -2.4000000000000004, -2.4000000000000004, -2.7],
#                'xaxis': 'x',
#                'y': [-11.203, -11.383, -11.383, -11.203, -11.203],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#808080',
#                'fillpattern': {'shape': '|'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('sterkZandigSilt'),
#                'line': {'color': '#808080'},
#                'mode': 'lines',
#                'name': np.str_('sterkZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -12.66<br>Thickness: 0.08'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.7, -2.7, -3.4],
#                'xaxis': 'x',
#                'y': [-12.582999999999998, -12.663, -12.663, -12.582999999999998,
#                      -12.582999999999998],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('sterkZandigSilt'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('sterkZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -12.66<br>Thickness: 0.08'),
#                'type': 'scatter',
#                'x': [-2.7, -2.7, -2.4000000000000004, -2.4000000000000004, -2.7],
#                'xaxis': 'x',
#                'y': [-12.582999999999998, -12.663, -12.663, -12.582999999999998,
#                      -12.582999999999998],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#808080',
#                'fillpattern': {'shape': '|'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('sterkZandigSilt'),
#                'line': {'color': '#808080'},
#                'mode': 'lines',
#                'name': np.str_('sterkZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -13.44<br>Thickness: 0.22'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.7, -2.7, -3.4],
#                'xaxis': 'x',
#                'y': [-13.222999999999999, -13.443000000000001, -13.443000000000001,
#                      -13.222999999999999, -13.222999999999999],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('sterkZandigSilt'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('sterkZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -13.44<br>Thickness: 0.22'),
#                'type': 'scatter',
#                'x': [-2.7, -2.7, -2.4000000000000004, -2.4000000000000004, -2.7],
#                'xaxis': 'x',
#                'y': [-13.222999999999999, -13.443000000000001, -13.443000000000001,
#                      -13.222999999999999, -13.222999999999999],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#808080',
#                'fillpattern': {'shape': '|'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('sterkZandigSilt'),
#                'line': {'color': '#808080'},
#                'mode': 'lines',
#                'name': np.str_('sterkZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -19.14<br>Thickness: 0.76'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.7, -2.7, -3.4],
#                'xaxis': 'x',
#                'y': [-18.383, -19.143, -19.143, -18.383, -18.383],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('sterkZandigSilt'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('sterkZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -19.14<br>Thickness: 0.76'),
#                'type': 'scatter',
#                'x': [-2.7, -2.7, -2.4000000000000004, -2.4000000000000004, -2.7],
#                'xaxis': 'x',
#                'y': [-18.383, -19.143, -19.143, -18.383, -18.383],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#964B00',
#                'fillpattern': {'shape': '-'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('veen'),
#                'line': {'color': '#964B00'},
#                'mode': 'lines',
#                'name': np.str_('veen'),
#                'showlegend': True,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'ayer: -0.68<br>Thickness: 0.40'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [-0.2829999999999995, -0.6829999999999998, -0.6829999999999998,
#                      -0.2829999999999995, -0.2829999999999995],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zand'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zand'),
#                'showlegend': True,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'layer: 4.58<br>Thickness: 0.56'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [5.1370000000000005, 4.577000000000001, 4.577000000000001,
#                      5.1370000000000005, 5.1370000000000005],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zand'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zand'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'layer: 4.08<br>Thickness: 0.50'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [4.577, 4.077, 4.077, 4.577, 4.577],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zand'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zand'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'layer: 3.70<br>Thickness: 0.38'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [4.077, 3.697, 3.697, 4.077, 4.077],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zand'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zand'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'layer: 1.92<br>Thickness: 1.78'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [3.697, 1.9170000000000003, 1.9170000000000003, 3.697, 3.697],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zand'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zand'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'layer: 0.10<br>Thickness: 0.16'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [0.25700000000000056, 0.09700000000000042, 0.09700000000000042,
#                      0.25700000000000056, 0.25700000000000056],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zand'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zand'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'ayer: -0.16<br>Thickness: 0.26'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [0.09700000000000042, -0.16300000000000026,
#                      -0.16300000000000026, 0.09700000000000042, 0.09700000000000042],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zand'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zand'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -11.72<br>Thickness: 0.34'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [-11.383, -11.722999999999999, -11.722999999999999, -11.383,
#                      -11.383],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zand'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zand'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -12.38<br>Thickness: 0.66'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [-11.722999999999999, -12.383, -12.383, -11.722999999999999,
#                      -11.722999999999999],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zand'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zand'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -12.86<br>Thickness: 0.20'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [-12.663, -12.863, -12.863, -12.663, -12.663],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zand'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zand'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -13.50<br>Thickness: 0.06'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [-13.443000000000001, -13.503, -13.503, -13.443000000000001,
#                      -13.443000000000001],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zand'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zand'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -13.62<br>Thickness: 0.12'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [-13.503, -13.623000000000001, -13.623000000000001, -13.503,
#                      -13.503],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zand'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zand'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -16.82<br>Thickness: 3.20'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [-13.623000000000001, -16.823, -16.823, -13.623000000000001,
#                      -13.623000000000001],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zand'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zand'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -16.94<br>Thickness: 0.12'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [-16.823, -16.943, -16.943, -16.823, -16.823],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zand'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zand'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -17.90<br>Thickness: 0.96'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [-16.943, -17.903, -17.903, -16.943, -16.943],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zand'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zand'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -18.38<br>Thickness: 0.44'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.4, -2.4, -3.4],
#                'xaxis': 'x',
#                'y': [-17.943, -18.383, -18.383, -17.943, -17.943],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#808080',
#                'fillpattern': {'shape': '|'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zwakZandigSilt'),
#                'line': {'color': '#808080'},
#                'mode': 'lines',
#                'name': np.str_('zwakZandigSilt'),
#                'showlegend': True,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'layer: 5.66<br>Thickness: 0.06'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.5, -2.5, -3.4],
#                'xaxis': 'x',
#                'y': [5.7170000000000005, 5.657000000000001, 5.657000000000001,
#                      5.7170000000000005, 5.7170000000000005],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zwakZandigSilt'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zwakZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'layer: 5.66<br>Thickness: 0.06'),
#                'type': 'scatter',
#                'x': [-2.5, -2.5, -2.4, -2.4, -2.5],
#                'xaxis': 'x',
#                'y': [5.7170000000000005, 5.657000000000001, 5.657000000000001,
#                      5.7170000000000005, 5.7170000000000005],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#808080',
#                'fillpattern': {'shape': '|'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zwakZandigSilt'),
#                'line': {'color': '#808080'},
#                'mode': 'lines',
#                'name': np.str_('zwakZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'layer: 0.60<br>Thickness: 0.46'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.5, -2.5, -3.4],
#                'xaxis': 'x',
#                'y': [1.0570000000000004, 0.5970000000000004, 0.5970000000000004,
#                      1.0570000000000004, 1.0570000000000004],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zwakZandigSilt'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zwakZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'layer: 0.60<br>Thickness: 0.46'),
#                'type': 'scatter',
#                'x': [-2.5, -2.5, -2.4, -2.4, -2.5],
#                'xaxis': 'x',
#                'y': [1.0570000000000004, 0.5970000000000004, 0.5970000000000004,
#                      1.0570000000000004, 1.0570000000000004],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#808080',
#                'fillpattern': {'shape': '|'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zwakZandigSilt'),
#                'line': {'color': '#808080'},
#                'mode': 'lines',
#                'name': np.str_('zwakZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'ayer: -0.24<br>Thickness: 0.04'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.5, -2.5, -3.4],
#                'xaxis': 'x',
#                'y': [-0.2029999999999994, -0.24299999999999944,
#                      -0.24299999999999944, -0.2029999999999994, -0.2029999999999994],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zwakZandigSilt'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zwakZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'ayer: -0.24<br>Thickness: 0.04'),
#                'type': 'scatter',
#                'x': [-2.5, -2.5, -2.4, -2.4, -2.5],
#                'xaxis': 'x',
#                'y': [-0.2029999999999994, -0.24299999999999944,
#                      -0.24299999999999944, -0.2029999999999994, -0.2029999999999994],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#808080',
#                'fillpattern': {'shape': '|'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zwakZandigSilt'),
#                'line': {'color': '#808080'},
#                'mode': 'lines',
#                'name': np.str_('zwakZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'ayer: -0.94<br>Thickness: 0.26'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.5, -2.5, -3.4],
#                'xaxis': 'x',
#                'y': [-0.6829999999999998, -0.9429999999999996, -0.9429999999999996,
#                      -0.6829999999999998, -0.6829999999999998],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zwakZandigSilt'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zwakZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'ayer: -0.94<br>Thickness: 0.26'),
#                'type': 'scatter',
#                'x': [-2.5, -2.5, -2.4, -2.4, -2.5],
#                'xaxis': 'x',
#                'y': [-0.6829999999999998, -0.9429999999999996, -0.9429999999999996,
#                      -0.6829999999999998, -0.6829999999999998],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#808080',
#                'fillpattern': {'shape': '|'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zwakZandigSilt'),
#                'line': {'color': '#808080'},
#                'mode': 'lines',
#                'name': np.str_('zwakZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'ayer: -3.74<br>Thickness: 0.30'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.5, -2.5, -3.4],
#                'xaxis': 'x',
#                'y': [-3.4429999999999996, -3.7430000000000003, -3.7430000000000003,
#                      -3.4429999999999996, -3.4429999999999996],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zwakZandigSilt'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zwakZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'ayer: -3.74<br>Thickness: 0.30'),
#                'type': 'scatter',
#                'x': [-2.5, -2.5, -2.4, -2.4, -2.5],
#                'xaxis': 'x',
#                'y': [-3.4429999999999996, -3.7430000000000003, -3.7430000000000003,
#                      -3.4429999999999996, -3.4429999999999996],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#808080',
#                'fillpattern': {'shape': '|'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zwakZandigSilt'),
#                'line': {'color': '#808080'},
#                'mode': 'lines',
#                'name': np.str_('zwakZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'ayer: -9.42<br>Thickness: 0.24'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.5, -2.5, -3.4],
#                'xaxis': 'x',
#                'y': [-9.183, -9.423, -9.423, -9.183, -9.183],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zwakZandigSilt'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zwakZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'ayer: -9.42<br>Thickness: 0.24'),
#                'type': 'scatter',
#                'x': [-2.5, -2.5, -2.4, -2.4, -2.5],
#                'xaxis': 'x',
#                'y': [-9.183, -9.423, -9.423, -9.183, -9.183],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#808080',
#                'fillpattern': {'shape': '|'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zwakZandigSilt'),
#                'line': {'color': '#808080'},
#                'mode': 'lines',
#                'name': np.str_('zwakZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -11.20<br>Thickness: 0.10'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.5, -2.5, -3.4],
#                'xaxis': 'x',
#                'y': [-11.103000000000002, -11.203, -11.203, -11.103000000000002,
#                      -11.103000000000002],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zwakZandigSilt'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zwakZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -11.20<br>Thickness: 0.10'),
#                'type': 'scatter',
#                'x': [-2.5, -2.5, -2.4, -2.4, -2.5],
#                'xaxis': 'x',
#                'y': [-11.103000000000002, -11.203, -11.203, -11.103000000000002,
#                      -11.103000000000002],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#808080',
#                'fillpattern': {'shape': '|'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zwakZandigSilt'),
#                'line': {'color': '#808080'},
#                'mode': 'lines',
#                'name': np.str_('zwakZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -13.22<br>Thickness: 0.16'),
#                'type': 'scatter',
#                'x': [-3.4, -3.4, -2.5, -2.5, -3.4],
#                'xaxis': 'x',
#                'y': [-13.062999999999999, -13.222999999999999, -13.222999999999999,
#                      -13.062999999999999, -13.062999999999999],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#FFFF00',
#                'fillpattern': {'shape': '.'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('zwakZandigSilt'),
#                'line': {'color': '#FFFF00'},
#                'mode': 'lines',
#                'name': np.str_('zwakZandigSilt'),
#                'showlegend': False,
#                'text': ('Name: CPT000000227712<br>Soil ' ... 'yer: -13.22<br>Thickness: 0.16'),
#                'type': 'scatter',
#                'x': [-2.5, -2.5, -2.4, -2.4, -2.5],
#                'xaxis': 'x',
#                'y': [-13.062999999999999, -13.222999999999999, -13.222999999999999,
#                      -13.062999999999999, -13.062999999999999],
#                'yaxis': 'y'},
#               {'marker': {'color': 'darkgray', 'size': 10},
#                'mode': 'markers',
#                'name': 'maaiveld sondering',
#                'showlegend': True,
#                'type': 'scatter',
#                'x': [-3.0],
#                'xaxis': 'x',
#                'y': [5.817],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#008000',
#                'fillpattern': {'shape': '/'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('klei'),
#                'line': {'color': '#008000'},
#                'mode': 'lines',
#                'name': np.str_('klei'),
#                'showlegend': False,
#                'text': ('Name: CPT000000228010<br>Soil ' ... 'layer: 5.36<br>Thickness: 0.22'),
#                'type': 'scatter',
#                'x': [-15.4, -15.4, -14.4, -14.4, -15.4],
#                'xaxis': 'x',
#                'y': [5.583, 5.363, 5.363, 5.583, 5.583],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#008000',
#                'fillpattern': {'shape': '/'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('klei'),
#                'line': {'color': '#008000'},
#                'mode': 'lines',
#                'name': np.str_('klei'),
#                'showlegend': False,
#                'text': ('Name: CPT000000228010<br>Soil ' ... 'layer: 1.16<br>Thickness: 0.16'),
#                'type': 'scatter',
#                'x': [-15.4, -15.4, -14.4, -14.4, -15.4],
#                'xaxis': 'x',
#                'y': [1.3230000000000004, 1.1630000000000003, 1.1630000000000003,
#                      1.3230000000000004, 1.3230000000000004],
#                'yaxis': 'y'},
#               {'fill': 'toself',
#                'fillcolor': '#008000',
#                'fillpattern': {'shape': '/'},
#                'hovertemplate': '%{text}',
#                'legendgroup': np.str_('klei'),
#                'line': {'color': '#008000'},
#                'mode': 'lines',
#                'name': np.str_('klei'),
#                'showlegend': False,
#                'text': ('Name: CPT000000228010<br>Soil ' ... 'layer: 0.76<br>Thickness: 0.36'),
#                'type': 'scatter',
#                'x': [-15.4, -15.4, -14.4, -14.4, -15.4],
#                'xaxis': 'x',
# ...
#                            Timestamp('2025-08-19 09:50:00+0000', tz='UTC'),
#                            Timestamp('2025-08-19 10:00:00+0000', tz='UTC'),
#                            Timestamp('2025-08-19 10:05:00+0000', tz='UTC')],
#                           shape=(82640,), dtype=object),
#                'xaxis': 'x2',
#                'y': {'bdata': ('AAAAAAAA+H9xPQrXo3D9P0jhehSuR/' ... 'A9Cvc/4XoUrkfh9j8AAAAAAAD4fw=='),
#                      'dtype': 'f8'},
#                'yaxis': 'y2'},
#               {'line': {'color': 'blue', 'width': 4},
#                'mode': 'lines',
#                'showlegend': False,
#                'type': 'scatter',
#                'x': [-2.710417348603532, -1.1104173486035318],
#                'xaxis': 'x',
#                'y': [1.5411766242145852, 1.5411766242145852],
#                'yaxis': 'y'},
#               {'line': {'color': 'blue', 'width': 2},
#                'mode': 'lines',
#                'name': 'pb kruin dp820.0 L',
#                'type': 'scatter',
#                'x': array([Timestamp('2024-01-23 12:52:00+0000', tz='UTC'),
#                            Timestamp('2024-05-24 01:10:00+0000', tz='UTC'),
#                            Timestamp('2024-05-24 01:20:00+0000', tz='UTC'), ...,
#                            Timestamp('2025-08-19 09:50:00+0000', tz='UTC'),
#                            Timestamp('2025-08-19 10:00:00+0000', tz='UTC'),
#                            Timestamp('2025-08-19 10:10:00+0000', tz='UTC')],
#                           shape=(65145,), dtype=object),
#                'xaxis': 'x2',
#                'y': {'bdata': ('AAAAAAAA+H89CtejcD36Pz0K16NwPf' ... 'oUrkfh9j/hehSuR+H2PwAAAAAAAPh/'),
#                      'dtype': 'f8'},
#                'yaxis': 'y2'}],
#      'layout': {'annotations': [{'font': {'color': 'black', 'size': 10},
#                                  'showarrow': False,
#                                  'text': 'CPT000000227712',
#                                  'textangle': 90,
#                                  'x': np.float64(-2.9),
#                                  'xanchor': 'left',
#                                  'xref': 'x',
#                                  'y': 1,
#                                  'yanchor': 'top',
#                                  'yref': 'y domain'},
#                                 {'bgcolor': 'green',
#                                  'bordercolor': 'black',
#                                  'borderwidth': 2,
#                                  'font': {'color': 'white', 'size': 12},
#                                  'showarrow': False,
#                                  'text': 'dp820.0 (-0)',
#                                  'textangle': -90,
#                                  'x': np.float64(-3.0),
#                                  'xanchor': 'center',
#                                  'y': 5.817,
#                                  'yanchor': 'bottom',
#                                  'yshift': 0},
#                                 {'font': {'color': 'black', 'size': 10},
#                                  'showarrow': False,
#                                  'text': 'CPT000000228010',
#                                  'textangle': 90,
#                                  'x': np.float64(-14.9),
#                                  'xanchor': 'left',
#                                  'xref': 'x',
#                                  'y': 1,
#                                  'yanchor': 'top',
#                                  'yref': 'y domain'},
#                                 {'bgcolor': 'green',
#                                  'bordercolor': 'black',
#                                  'borderwidth': 2,
#                                  'font': {'color': 'white', 'size': 12},
#                                  'showarrow': False,
#                                  'text': 'dp820.0 (-0)',
#                                  'textangle': -90,
#                                  'x': np.float64(-15.0),
#                                  'xanchor': 'center',
#                                  'y': 5.663,
#                                  'yanchor': 'bottom',
#                                  'yshift': 0},
#                                 {'font': {'color': 'black', 'size': 10},
#                                  'showarrow': False,
#                                  'text': 'CPT000000227661',
#                                  'textangle': 90,
#                                  'x': np.float64(-15.9),
#                                  'xanchor': 'left',
#                                  'xref': 'x',
#                                  'y': 1,
#                                  'yanchor': 'top',
#                                  'yref': 'y domain'},
#                                 {'bgcolor': 'firebrick',
#                                  'bordercolor': 'black',
#                                  'borderwidth': 2,
#                                  'font': {'color': 'white', 'size': 12},
#                                  'showarrow': False,
#                                  'text': 'dp819.5 (-1)',
#                                  'textangle': -90,
#                                  'x': np.float64(-16.0),
#                                  'xanchor': 'center',
#                                  'y': 4.768,
#                                  'yanchor': 'bottom',
#                                  'yshift': 0},
#                                 {'font': {'color': 'black', 'size': 10},
#                                  'showarrow': False,
#                                  'text': 'CPT000000227761',
#                                  'textangle': 90,
#                                  'x': np.float64(-16.9),
#                                  'xanchor': 'left',
#                                  'xref': 'x',
#                                  'y': 1,
#                                  'yanchor': 'top',
#                                  'yref': 'y domain'},
#                                 {'bgcolor': 'navy',
#                                  'bordercolor': 'black',
#                                  'borderwidth': 2,
#                                  'font': {'color': 'white', 'size': 12},
#                                  'showarrow': False,
#                                  'text': 'dp820.5 (0)',
#                                  'textangle': -90,
#                                  'x': np.float64(-17.0),
#                                  'xanchor': 'center',
#                                  'y': 2.734,
#                                  'yanchor': 'bottom',
#                                  'yshift': 0},
#                                 {'font': {'color': 'black', 'size': 10},
#                                  'showarrow': False,
#                                  'text': 'CPT000000227744',
#                                  'textangle': 90,
#                                  'x': np.float64(-1.9),
#                                  'xanchor': 'left',
#                                  'xref': 'x',
#                                  'y': 1,
#                                  'yanchor': 'top',
#                                  'yref': 'y domain'},
#                                 {'bgcolor': 'red',
#                                  'bordercolor': 'black',
#                                  'borderwidth': 2,
#                                  'font': {'color': 'white', 'size': 12},
#                                  'showarrow': False,
#                                  'text': 'dp819.0 (0)',
#                                  'textangle': -90,
#                                  'x': np.float64(-2.0),
#                                  'xanchor': 'center',
#                                  'y': 6.096,
#                                  'yanchor': 'bottom',
#                                  'yshift': 0},
#                                 {'font': {'color': 'black', 'size': 10},
#                                  'showarrow': False,
#                                  'text': 'CPT000000227816',
#                                  'textangle': 90,
#                                  'x': np.float64(-19.9),
#                                  'xanchor': 'left',
#                                  'xref': 'x',
#                                  'y': 1,
#                                  'yanchor': 'top',
#                                  'yref': 'y domain'},
#                                 {'bgcolor': 'red',
#                                  'bordercolor': 'black',
#                                  'borderwidth': 2,
#                                  'font': {'color': 'white', 'size': 12},
#                                  'showarrow': False,
#                                  'text': 'dp819.0 (-0)',
#                                  'textangle': -90,
#                                  'x': np.float64(-20.0),
#                                  'xanchor': 'center',
#                                  'y': 1.589,
#                                  'yanchor': 'bottom',
#                                  'yshift': 0},
#                                 {'font': {'color': 'black', 'size': 10},
#                                  'showarrow': False,
#                                  'text': 'CPT000000227929',
#                                  'textangle': 90,
#                                  'x': np.float64(-18.9),
#                                  'xanchor': 'left',
#                                  'xref': 'x',
#                                  'y': 1,
#                                  'yanchor': 'top',
#                                  'yref': 'y domain'},
#                                 {'bgcolor': 'blue',
#                                  'bordercolor': 'black',
#                                  'borderwidth': 2,
#                                  'font': {'color': 'white', 'size': 12},
#                                  'showarrow': False,
#                                  'text': 'dp821.0 (1)',
#                                  'textangle': -90,
#                                  'x': np.float64(-19.0),
#                                  'xanchor': 'center',
#                                  'y': 0.943,
#                                  'yanchor': 'bottom',
#                                  'yshift': 0},
#                                 {'font': {'color': 'black', 'size': 10},
#                                  'showarrow': False,
#                                  'text': 'CPT000000227999',
#                                  'textangle': 90,
#                                  'x': np.float64(-0.9),
#                                  'xanchor': 'left',
#                                  'xref': 'x',
#                                  'y': 1,
#                                  'yanchor': 'top',
#                                  'yref': 'y domain'},
#                                 {'bgcolor': 'blue',
#                                  'bordercolor': 'black',
#                                  'borderwidth': 2,
#                                  'font': {'color': 'white', 'size': 12},
#                                  'showarrow': False,
#                                  'text': 'dp821.0 (1)',
#                                  'textangle': -90,
#                                  'x': np.float64(-1.0),
#                                  'xanchor': 'center',
#                                  'y': 6.218,
#                                  'yanchor': 'bottom',
#                                  'yshift': 0}],
#                 'images': [{'layer': 'below',
#                             'opacity': 0.8,
#                             'sizex': 65.43092442040764,
#                             'sizey': 23.80713608628912,
#                             'sizing': 'stretch',
#                             'source': ('...' ... '/4bwpY79S8PgAAAABJRU5ErkJggg=='),
#                             'x': -33.710864292657504,
#                             'xref': 'x',
#                             'y': 11.002954443109452,
#                             'yref': 'y'}],
#                 'legend': {'orientation': 'h', 'x': 0.5, 'xanchor': 'center', 'y': -0.2, 'yanchor': 'top'},
#                 'shapes': [{'line': {'color': 'Black', 'dash': 'dash', 'width': 1},
#                             'type': 'line',
#                             'x0': np.float64(-2.9),
#                             'x1': np.float64(-2.9),
#                             'xref': 'x',
#                             'y0': 0,
#                             'y1': 1,
#                             'yref': 'y domain'},
#                            {'line': {'color': 'Black', 'dash': 'dash', 'width': 1},
#                             'type': 'line',
#                             'x0': np.float64(-14.9),
#                             'x1': np.float64(-14.9),
#                             'xref': 'x',
#                             'y0': 0,
#                             'y1': 1,
#                             'yref': 'y domain'},
#                            {'line': {'color': 'Black', 'dash': 'dash', 'width': 1},
#                             'type': 'line',
#                             'x0': np.float64(-15.9),
#                             'x1': np.float64(-15.9),
#                             'xref': 'x',
#                             'y0': 0,
#                             'y1': 1,
#                             'yref': 'y domain'},
#                            {'line': {'color': 'Black', 'dash': 'dash', 'width': 1},
#                             'type': 'line',
#                             'x0': np.float64(-16.9),
#                             'x1': np.float64(-16.9),
#                             'xref': 'x',
#                             'y0': 0,
#                             'y1': 1,
#                             'yref': 'y domain'},
#                            {'line': {'color': 'Black', 'dash': 'dash', 'width': 1},
#                             'type': 'line',
#                             'x0': np.float64(-1.9),
#                             'x1': np.float64(-1.9),
#                             'xref': 'x',
#                             'y0': 0,
#                             'y1': 1,
#                             'yref': 'y domain'},
#                            {'line': {'color': 'Black', 'dash': 'dash', 'width': 1},
#                             'type': 'line',
#                             'x0': np.float64(-19.9),
#                             'x1': np.float64(-19.9),
#                             'xref': 'x',
#                             'y0': 0,
#                             'y1': 1,
#                             'yref': 'y domain'},
#                            {'line': {'color': 'Black', 'dash': 'dash', 'width': 1},
#                             'type': 'line',
#                             'x0': np.float64(-18.9),
#                             'x1': np.float64(-18.9),
#                             'xref': 'x',
#                             'y0': 0,
#                             'y1': 1,
#                             'yref': 'y domain'},
#                            {'line': {'color': 'Black', 'dash': 'dash', 'width': 1},
#                             'type': 'line',
#                             'x0': np.float64(-0.9),
#                             'x1': np.float64(-0.9),
#                             'xref': 'x',
#                             'y0': 0,
#                             'y1': 1,
#                             'yref': 'y domain'}],
#                 'template': '...',
#                 'title': {'font': {'color': 'red', 'size': 16},
#                           'text': 'profiel rondom dp820 ± 100m, tekening Deltaversterking bij dp818.1 (-190m)'},
#                 'xaxis': {'anchor': 'y',
#                           'domain': [0.0, 1.0],
#                           'range': [-30, 20],
#                           'title': {'text': 'afstand tot referentie lijn [m]'}},
#                 'xaxis2': {'anchor': 'y2',
#                            'domain': [0.0, 1.0],
#                            'range': [2024-01-23 12:52:00+00:00, 2025-08-19
#                                      10:10:00+00:00]},
#                 'yaxis': {'anchor': 'x', 'domain': [0.575, 1.0], 'range': [-4, 7], 'title': {'text': '(m NAP)'}},
#                 'yaxis2': {'anchor': 'x2', 'domain': [0.0, 0.425], 'title': {'text': 'grondwaterstand (m NAP)'}}}
#  }),
#  'N27-2_plots\\\\\\profiel_dp820__plusmin1.html')

# %%
df_plot
# Out:
#                              broId  tubeNumber constructionStandard  \
# bro_identifier
# GMW000000082245-1  GMW000000082245           1              NEN5766
# GMW000000082245-2  GMW000000082245           2              NEN5766
# GMW000000082255-1  GMW000000082255           1              NEN5766
# GMW000000082255-2  GMW000000082255           2              NEN5766
#
#                   coordinateTransformation corrected  \
# bro_identifier
# GMW000000082245-1           RDNAPTRANS2018       nee
# GMW000000082245-2           RDNAPTRANS2018       nee
# GMW000000082255-1           RDNAPTRANS2018       nee
# GMW000000082255-2           RDNAPTRANS2018       nee
#
#                               deliveredLocation  deliveryAccountableParty  \
# bro_identifier
# GMW000000082245-1  POINT (63121.737 403079.799)                  51640813
# GMW000000082245-2  POINT (63121.737 403079.799)                  51640813
# GMW000000082255-1   POINT (63123.327 403066.59)                  51640813
# GMW000000082255-2   POINT (63123.327 403066.59)                  51640813
#
#                   deliveryContext deregistered  groundLevelPosition  ...  \
# bro_identifier                                                       ...
# GMW000000082245-1              WW          nee                 5.89  ...
# GMW000000082245-2              WW          nee                 5.89  ...
# GMW000000082255-1              WW          nee                 5.83  ...
# GMW000000082255-2              WW          nee                 5.83  ...
#
#                   sedimentSumpLength          x           y  \
# bro_identifier
# GMW000000082245-1                0.5  63121.737  403079.799
# GMW000000082245-2                1.0  63121.737  403079.799
# GMW000000082255-1                1.0  63123.327  403066.590
# GMW000000082255-2                1.0  63123.327  403066.590
#
#                                        geometry ref_distance      dp  \
# bro_identifier
# GMW000000082245-1  POINT (63121.737 403079.799)      81999.0  819.99
# GMW000000082245-2  POINT (63121.737 403079.799)      81999.0  819.99
# GMW000000082255-1   POINT (63123.327 403066.59)      81999.0  819.99
# GMW000000082255-2   POINT (63123.327 403066.59)      81999.0  819.99
#
#                    distance_to_ref region  position       label
# bro_identifier
# GMW000000082245-1        -1.910417     Os  broloket  GMW82245-1
# GMW000000082245-2        -1.910417     Os  broloket  GMW82245-2
# GMW000000082255-1       -15.211451     Os  broloket  GMW82255-1
# GMW000000082255-2       -15.211451     Os  broloket  GMW82255-2
#
# [4 rows x 61 columns]

# %%
df_gmws.dp.unique()
# Out:
# array([ 784.37,  784.43, 1081.5 , 1081.51,  180.01,  157.99,  175.01,
#         179.99,  151.98,  174.95,  145.99,  171.02,  171.  ,  140.01,
#         152.01,  398.  ,  395.  ,  401.01,  400.94,  206.28,  206.27,
#         206.72,  205.85,  207.  ,  789.02,  796.99,  793.  ,  792.99,
#         789.01,  931.07, 1020.  ,  868.75,  893.95,  997.  ,  869.56,
#         882.04,  894.  , 1052.  ,  917.09,  866.04, 1012.  ,  868.67,
#        1029.  ,  930.5 ,  819.99,  853.98, 1076.01,  882.06,  866.03,
#         869.93,  853.99,  917.06,  917.07,  970.01,  987.93,  975.  ,
#         987.99,  980.  ,  969.99, 1502.67, 1503.  , 1503.05, 1504.17,
#        1504.08, 1503.54, 1501.36, 1505.79, 1506.  , 1501.01, 1460.09,
#        1461.01,  955.02,  783.11,  783.02,  971.05,  135.33, 1080.12,
#          43.86, 1020.19, 1010.  ,  961.  ,  969.95,  982.99, 1000.02,
#          43.88,  982.79,  367.76,  777.51, 1025.  ,  367.04,  963.99,
#         995.79, 1005.01,  940.99,  367.89,  995.99,  135.52,  781.65,
#         777.5 , 1067.98,  368.05,  781.63,  941.  ,  991.  , 1015.  ,
#        1000.  ,  970.62,  934.99, 1027.97, 1047.15,   41.5 ,  945.99,
#         367.32,  935.02,  738.01,  738.  ,  748.99,  749.  ,  761.99,
#         762.  ,  772.  ])

# %% [markdown]
# Section that includes 2 hectometers (dp) behind and ahead.

# %%
if 0:
    fig, fn = gl.create_figure_for_dp(
        820,
        df_section, 
        geoprofile_cols, 
        df_profiles,
        oc_gwl,
        delta_dp=2,
        plot_path=PLOT_PATH,
        )
