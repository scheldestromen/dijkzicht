# %% [markdown]
# # Example N27-2
#
# Get an overview of levee charcateristics for levee trajectory 27-2.
#
# Thanks to package `GeoProfile` that allows to visualise geotechnical data in Python.

# %%
import os
import pickle
import pandas as pd
import numpy as np

import datetime

import logging
#logging.basicConfig(level=logging.WARNING)
#logging.basicConfig(level=logging.INFO)
# when logging level = DEBUG, skip messages from matplotlib and PIL
logging.basicConfig(level=logging.DEBUG)
for lib in ['rasterio', 'matplotlib', 'PIL', 'urllib3', 'choreographer', 'kaleido']:
    logging.getLogger(lib).setLevel(logging.INFO)

# %%
import hydropandas as hpd
hpd.__version__
# Out:
# '0.18.0'

# %%
import geoprofile
geoprofile.__version__
# Out:
# '0.4.0'

# %%
# TODO: De functies van `geolookup` staan nu allemaal in een .py bestand. Dit nog Python-ic maken. Met een init.py en verschillende sub besatanden
# TODO: geheel Object Oriented maken

# %%
import sys
sys.path.append(r'..\..\geolookup')

import functions as gl

# %% [markdown]
# # Gegevens openen

# %%
DATA_PATH = r'N27-2_data\\'
PLOT_PATH = r'N27-2_plots\\'

# %% [markdown]
# ## CPTs
#
# Downloaded from Broloket and classified via `CPTcore` using Robertson classification.

# %%
# TODO: change method to plot CPTs in section perpendicular to levee. Now data is projected using Waterschap Scheldestromen method to
# project CPTs relative to reference line (x=0). Therefore, preprocessing is done outside this repo.

# %%
region = 'Os'
dp_min = 725
dp_max = 1080
cpt_classification = 'Robertson'

fn = DATA_PATH + f'geoprofile_columns_robertson_{region}_dp{dp_min}-{dp_max}.pkl'
logging.info(f"File last modified: {datetime.datetime.fromtimestamp(os.path.getmtime(fn)) - datetime.datetime.now()}")
with open(fn, "rb") as f:
    geoprofile_cols = pickle.load(f)
gl.describe_columns(geoprofile_cols)
# Out:
# INFO:root:File last modified: -6 days, 7:42:49.210544
# INFO:root:Number of columns: 1248
# INFO:root:Dike pole range: dp726.6 - dp1081.5, total 759 unique dike poles.
# INFO:root:Data X: centered at 64380 with span 13 km, Y: centered at 397930 with span 11 km

# %% [markdown]
# ## Hectometer indicator

# %%
df_hm = pd.read_csv(DATA_PATH + f'table_dijkpalen_{region}_dp{dp_min}-{dp_max}.csv')
df_hm.dp.describe()
# Out:
# count     711.000000
# mean      902.500000
# std       102.696154
# min       725.000000
# 25%       813.750000
# 50%       902.500000
# 75%       991.250000
# max      1080.000000
# Name: dp, dtype: float64

# %% [markdown]
# ## Schematised levee profiles

# %%
df_profile = pd.read_csv(DATA_PATH + f'table_profielen_{region}_dp{dp_min}-{dp_max}.csv')
df_profile.head()
# Out:
#   region     dp  ymv.bui  ysloot.1d  xmv.bin  xsloot.1a  xsloot.1c  xsloot.1d  \
# 0     Os  725.0   -0.253       -0.5   -91.13     -52.13     -50.79     -50.39
# 1     Os  726.0   -0.583        0.0  -200.88     -97.88     -95.77     -92.82
# 2     Os  727.0   -0.928        0.5   -51.22     -23.22     -21.81     -20.57
# 3     Os  728.0   -0.926        0.5  -201.00     -24.00     -22.64     -22.60
# 4     Os  729.0   -1.034        0.5  -201.00     -23.62     -22.34     -20.45
#
#    xsloot.1b  xweg.1  ...  yteen.1  yberm.1a  yberm.1b  ykruin.1  ykruin.2  \
# 0     -49.13  -25.13  ...     1.71      6.26      6.39      6.39      6.22
# 1     -90.88  -18.88  ...     2.45      6.43      6.43      6.43      6.41
# 2     -19.22  -19.22  ...     2.08      6.51      6.51      6.51      6.43
# 3     -21.00  -21.00  ...     1.86      6.45      6.45      6.45      6.37
# 4     -19.00  -19.00  ...     1.50      6.46      6.46      6.46      6.42
#
#    yberm.2a  yberm.2b  yteen.2  yweg.2  ysloot.2
# 0      4.63      4.33     0.03   0.773    -0.071
# 1      4.58      4.28     0.05  -0.700    -0.640
# 2      4.53      4.27    -0.74  -0.776    -0.776
# 3      4.44      4.23     0.26  -0.130    -0.929
# 4      4.48      4.25    -0.76  -1.046    -0.936
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Section profiles
#
# Distance along trajectory where drawing (section profile) is available.

# %%
dp_fig = 971.3
dp_center = 971
fn = df_section.loc[df_section.dp == dp_fig, 'dsn_file_tif'].values[0]

print(fn)
from plotly.subplots import make_subplots
import plotly.io as pio

figure = make_subplots(
        rows=1,
        cols=1,
        horizontal_spacing=0.01,
    )

gl.plot_deltaversterking_background(figure, fn, dp=None, fig_row=1, fig_col=1, x_offset=-9)

gl.select_and_plot_surfacelevelprofile(dp_center, figure, df_profile, delta_dp=0, region='Os', fig_row=1, fig_col=1)

figure.update_xaxes(range=[-30, 20], row=1, col=1)

pio.write_html(figure, file=r'c:\temp\test.html', auto_open=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 dp_fig = 971.3
#       2 dp_center = 971
# ----> 3 fn = df_section.loc[df_section.dp == dp_fig, 'dsn_file_tif'].values[0]
#       5 print(fn)
#       6 from plotly.subplots import make_subplots
#
# NameError: name 'df_section' is not defined

# %%
df_section = pd.read_csv(DATA_PATH + f'table_deltaversterking_{region}_dp{dp_min}-{dp_max}.csv')
df_section['description'] = 'Deltaversterking'
df_section.dsn_file_tif = DATA_PATH + df_section.dsn_file_tif 

df_section['x_offset'] = 0
df_section.loc[df_section.dp == 725.5, 'x_offset'] = -8
df_section.loc[df_section.dp == 730.5, 'x_offset'] = 3
df_section.loc[df_section.dp == 736.5, 'x_offset'] = -5
df_section.loc[df_section.dp == 744.9, 'x_offset'] = -6
df_section.loc[df_section.dp == 753.1, 'x_offset'] = -5
df_section.loc[df_section.dp == 873.2, 'x_offset'] = -5
df_section.loc[df_section.dp == 940, 'x_offset'] = 5
df_section.loc[df_section.dp == 945, 'x_offset'] = 5
df_section.loc[df_section.dp == 950, 'x_offset'] = 7
df_section.loc[df_section.dp == 953, 'x_offset'] = -8
df_section.loc[df_section.dp == 956.8, 'x_offset'] = -9
df_section.loc[df_section.dp == 961.5, 'x_offset'] = -9
df_section.loc[df_section.dp == 964, 'x_offset'] = -9
df_section.loc[df_section.dp == 968.8, 'x_offset'] = -10
df_section.loc[df_section.dp == 971.3, 'x_offset'] = -9



df_section.head()
# Out:
#   region     dp                                       dsn_file_tif  \
# 0     Os  725.5  N27-2_data\\deltaversterking\os0725-0778\doors...
# 1     Os  730.5  N27-2_data\\deltaversterking\os0725-0778\doors...
# 2     Os  734.5  N27-2_data\\deltaversterking\os0725-0778\doors...
# 3     Os  736.5  N27-2_data\\deltaversterking\os0725-0778\doors...
# 4     Os  744.9  N27-2_data\\deltaversterking\os0725-0778\doors...
#
#         description  x_offset
# 0  Deltaversterking        -8
# 1  Deltaversterking         3
# 2  Deltaversterking         0
# 3  Deltaversterking        -5
# 4  Deltaversterking        -6

# %% [markdown]
# ## Groundwater monitoring and time series
# Using `HydroPandas`

# %%
#TODO: functie maken die ouderom netjes aangeeft, als > dag, in dagen, anders in uren, anders in minuten
fn = DATA_PATH + f'oc_gwl_{region}_dp{dp_min}-{dp_max}.pkl'
oc_gwl = hpd.read_pickle(fn)
logging.info(f"File last modified: {(datetime.datetime.fromtimestamp(os.path.getmtime(fn)) - datetime.datetime.now()).total_seconds() / 60:.2f} minutes")
gl.describe_oc(oc_gwl, expected_obs_interval=10)
# Out:
# INFO:root:File last modified: -8221.81 minutes
# INFO:root:Obs Collection has 85 monitoring wells, on 66 locations. First observation 2007-08-29, last observation 2025-11-22
# INFO:root:Obs Collection has on average 1.1 years of observations per monitoring well, median 1.3 years. Assuming observations interval each 10 minutes.
# INFO:root:Data X: centered at 64220 with span 13 km, Y: centered at 397920 with span 10 km
# INFO:root:Index is unique.

# %% [markdown]
# ## Broloket

# %%
# not all standpipes are in Broloket at the moment (work in progess, I know)
# standpipes that are in Broloket are downloaded, distances along and perpendicular to levee added
df_gmw = pd.read_csv(DATA_PATH + 'gmws_met_dp_en_afstanden.csv', index_col=0)
df_gmw = df_gmw.rename(columns={'screenTopPosition': 'screen_top',
                        'screenBottomPosition': 'screen_bottom',})

df_gmw = df_gmw.loc[(df_gmw.region == 'Os') & (df_gmw.dp >= 725) & (df_gmw.dp <= 1080), :].copy()

df_gmw = df_gmw.sort_values(by=['dp', 'distance_to_ref', 'screen_top'], ascending=[True, True, False])

# Extract the number of zeros after the first three characters (e.g., after 'GMW')
min_padding_zeros = (
    df_gmw.index.str[3:]
    .str.extract(r'^(0+)')[0]
    .str.len()
    .min()
)
print("Minimum number of padding zeros in index:", min_padding_zeros)

df_gmw['label'] = df_gmw.index.str.replace(
    r'^(GMW)(0{%d})' % min_padding_zeros, r'\1', regex=True
)

df_gmw['position'] = 'dummy' # to be filled later

print("Is index unique?", df_gmw.index.is_unique)
df_gmw.head()
# Out:
# Minimum number of padding zeros in index: 6
# Is index unique? True
#                              broId  tubeNumber constructionStandard  \
# bro_identifier
# GMW000000114193-1  GMW000000114193           1              NEN5766
# GMW000000114192-2  GMW000000114192           2              NEN5766
# GMW000000114192-1  GMW000000114192           1              NEN5766
# GMW000000114191-1  GMW000000114191           1              NEN5766
# GMW000000114194-2  GMW000000114194           2              NEN5766
#
#                   coordinateTransformation corrected  \
# bro_identifier
# GMW000000114193-1           RDNAPTRANS2018       nee
# GMW000000114192-2           RDNAPTRANS2018       nee
# GMW000000114192-1           RDNAPTRANS2018       nee
# GMW000000114191-1           RDNAPTRANS2018       nee
# GMW000000114194-2           RDNAPTRANS2018       nee
#
#                               deliveredLocation  deliveryAccountableParty  \
# bro_identifier
# GMW000000114193-1  POINT (69886.014 402104.846)                  51640813
# GMW000000114192-2  POINT (69874.797 402107.579)                  51640813
# GMW000000114192-1  POINT (69874.797 402107.579)                  51640813
# GMW000000114191-1  POINT (69899.803 402101.262)                  51640813
# GMW000000114194-2  POINT (68987.515 401720.047)                  51640813
#
#                   deliveryContext deregistered  groundLevelPosition  ...  \
# bro_identifier                                                       ...
# GMW000000114193-1              WW          nee                6.203  ...
# GMW000000114192-2              WW          nee                4.315  ...
# GMW000000114192-1              WW          nee                4.315  ...
# GMW000000114191-1              WW          nee                1.216  ...
# GMW000000114194-2              WW          nee                1.405  ...
#
#                   sedimentSumpLength          x           y  \
# bro_identifier
# GMW000000114193-1                1.0  69886.014  402104.846
# GMW000000114192-2                1.0  69874.797  402107.579
# GMW000000114192-1                1.0  69874.797  402107.579
# GMW000000114191-1                1.0  69899.803  402101.262
# GMW000000114194-2                1.0  68987.515  401720.047
#
#                                        geometry ref_distance      dp  \
# bro_identifier
# GMW000000114193-1  POINT (69886.014 402104.846)      73800.0  738.00
# GMW000000114192-2  POINT (69874.797 402107.579)      73800.0  738.00
# GMW000000114192-1  POINT (69874.797 402107.579)      73800.0  738.00
# GMW000000114191-1  POINT (69899.803 402101.262)      73801.0  738.01
# GMW000000114194-2  POINT (68987.515 401720.047)      74899.0  748.99
#
#                    distance_to_ref region        label  position
# bro_identifier
# GMW000000114193-1        -1.637064     Os  GMW114193-1     dummy
# GMW000000114192-2         9.895985     Os  GMW114192-2     dummy
# GMW000000114192-1         9.895985     Os  GMW114192-1     dummy
# GMW000000114191-1       -15.857655     Os  GMW114191-1     dummy
# GMW000000114194-2       -15.077116     Os  GMW114194-2     dummy
#
# [5 rows x 61 columns]

# %% [markdown]
# # Section along the trajectory of the levee
#
# Using the standard `profile` function of `GeoProfile`. It is called within a specific `GeoLookup` function, that creates the path.
# Afterwards levee charecteristics are added to the plot. That uses the `dp` (hectometer) property of these data sets.
#
# Section opens in a browser window. Map is included below.

# %%
if 0:
    region = 'Os'
    dp_list = [818, 821]
    dp_list = np.arange(818, 821+1)
    #dp_list = [930, 936]
    fig, profile = gl.plot_geoprofile(
        geoprofile_cols, 
        df_hm, 
        dp_list,
        oc_gwl=oc_gwl, 
        buffer=60, 
        projectname=f"Along levee {region} {min(dp_list)}-{max(dp_list)} {cpt_classification}",
        title_suffix='',
        plot_path=PLOT_PATH,)

# %%
# TODO: plotting of standpipes via oc_gwl is not working visible in maps. Annotation is plotted, legend as well. Standpipe itself not visible.

# %% [markdown]
# # Doorsnede maken bij dijkpaal
#
# Een doorsnede haaks op de dijk, ter hoogte van een dijkpaal. Weergegeven wordt het beschikbare grondonderzoek, de dichtstbijzijnde versterkingstekening van de Deltaversterking, het actuele maaiveld profiel en de peilbuizen.
#
# Informatie van meerdere dijkpalen wordt weergegeven wanneer de `delta_dp` variabele wort gebuikt. Informatie van lagere dijkpalen krijgt een rode tint, informatie van hogere dijkpalen een blauwe.
#
# Grondonderzoek wordt geprojecteerd ten opzichte van de referentielijn. Het wordt nooit bovenopelkaargeplot. Dan krijgt het een offset. Die offset is weergegeven tussen de haakjes in het label. Grondonderzoek van de opgevraagde raai wordt als eerste geplot, en staat dus vrijwel altijd op de juiste plek.

# %%
dp_center = 725
delta_dp = 2

fig, fn = gl.create_figure_for_dp(
    dp_center, 
    df_section, 
    geoprofile_cols, 
    df_profile,
    oc_gwl,
    df_gmw=df_gmw,
    delta_dp=delta_dp,
    plot_gwl=True,
    plot_path=PLOT_PATH,
    ylims_upper=[-4, 7]
    )
# Out:
# DEBUG:root:Closest dp with Deltaversterking to 725 is 725.5, fn: es\dsn12_flipped.tif, x_offset: -8
# DEBUG:root:Adding Deltaversterking background from 8\doorsnedes\dsn12_flipped.tif to figure at row 1, col 1.
# DEBUG:root:Plotting column dp 726.6, distance=-23.5211947338196, plotted=[np.float64(-24.0)]
# DEBUG:root:Plotting column dp 727.0, distance=-14.597415089285775, plotted=[np.float64(-24.0), np.float64(-15.0)]
# DEBUG:root:Plotting column dp 727.0, distance=-1.3049853719405646, plotted=[np.float64(-24.0), np.float64(-15.0), np.float64(-1.0)]
# DEBUG:root:Closest dp with surface level profile to 725 is 725.0
# WARNING:root:No standpipes to plot in figure. ObsCollection is empty.
# DEBUG:root:gmw worden geplot, aantal: 0
# WARNING:root:No standpipes to plot in figure. ObsCollection is empty.
# DEBUG:asyncio:Using selector: SelectSelector
# INFO:choreographer.browsers.chromium:Chromium init'ed with kwargs {}
# DEBUG:root:Looking for browser, skipping local? False
# DEBUG:root:Looking for at local chrome download path: C:\Users\HMEUW\.conda\envs\wk20260129\Lib\site-packages\choreographer\cli\browser_exe\chrome-win64\chrome.exe
# DEBUG:root:Local chrome not found at path: C:\Users\HMEUW\.conda\envs\wk20260129\Lib\site-packages\choreographer\cli\browser_exe\chrome-win64\chrome.exe.
# INFO:choreographer.browsers.chromium:Found chromium path: C:\Program Files\Google\Chrome\Application\chrome.exe
# INFO:choreographer.utils._tmpfile:Temp directory created: C:\Users\HMEUW\AppData\Local\Temp\tmpqfe4ii5g.
# INFO:choreographer.browser_async:Opening browser.
# INFO:choreographer.utils._tmpfile:Temp directory created: C:\Users\HMEUW\AppData\Local\Temp\tmpho22mfp6.
# INFO:choreographer.browsers.chromium:Temporary directory at: C:\Users\HMEUW\AppData\Local\Temp\tmpho22mfp6
# DEBUG:browser_proc:[INFO:components\enterprise\browser\controller\chrome_browser_cloud_management_controller.cc:206] No machine level policy manager exists.
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\external_pref_loader.cc:296] You are using an old-style extension deployment method (external_extensions.json), which will soon be deprecated. (see http://developer.chrome.com/docs/extensions/how-to/distribute/install-extensions)
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\external_registry_loader_win.cc:236] Error observing HKLM: Toegang geweigerd. (0x5)
# INFO:kaleido.kaleido:Conforming 1 to file:///C:/Users/HMEUW/AppData/Local/Temp/tmpqfe4ii5g/index.html
# INFO:kaleido.kaleido:Waiting on all navigates
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\forced_extensions\force_installed_metrics.cc:511] All forced extensions seem to be installed
# INFO:kaleido.kaleido:All navigates done, putting them all in queue.
# INFO:kaleido.kaleido:Getting tab from queue (has 1)
# INFO:kaleido.kaleido:Got 8825
# INFO:kaleido._kaleido_tab:Processing profiel_rondom_dp725__200m_tekening_Deltaversterking_bij_dp7255_50m.png
# INFO:kaleido._kaleido_tab:Sending big command for profiel_rondom_dp725__200m_tekening_Deltaversterking_bij_dp7255_50m.png.
# INFO:kaleido._kaleido_tab:Sent big command for profiel_rondom_dp725__200m_tekening_Deltaversterking_bij_dp7255_50m.png.
# INFO:kaleido.kaleido:Reloading tab 8825 before return.
# INFO:kaleido.kaleido:Putting tab 8825 back (queue size: 0).
# INFO:kaleido.kaleido:Waiting for all cleanups to finish.
# INFO:kaleido.kaleido:Exiting Kaleido
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo

# %% [markdown]
# Section that includes no space behind and ahead.

# %%
fig, fn = gl.create_figure_for_dp(
    dp_center,
    df_section, 
    geoprofile_cols, 
    df_profile,
    oc_gwl,
    delta_dp=0,
    plot_path=PLOT_PATH,
    )
# Out:
# DEBUG:root:Closest dp with Deltaversterking to 725 is 725.5, fn: es\dsn12_flipped.tif, x_offset: -8
# DEBUG:root:Adding Deltaversterking background from 8\doorsnedes\dsn12_flipped.tif to figure at row 1, col 1.
# DEBUG:root:Closest dp with surface level profile to 725 is 725.0
# WARNING:root:No standpipes to plot in figure. ObsCollection is empty.
# DEBUG:root:gmw worden niet geplot
# DEBUG:asyncio:Using selector: SelectSelector
# INFO:choreographer.browsers.chromium:Chromium init'ed with kwargs {}
# DEBUG:root:Looking for browser, skipping local? False
# DEBUG:root:Looking for at local chrome download path: C:\Users\HMEUW\.conda\envs\wk20260129\Lib\site-packages\choreographer\cli\browser_exe\chrome-win64\chrome.exe
# DEBUG:root:Local chrome not found at path: C:\Users\HMEUW\.conda\envs\wk20260129\Lib\site-packages\choreographer\cli\browser_exe\chrome-win64\chrome.exe.
# INFO:choreographer.browsers.chromium:Found chromium path: C:\Program Files\Google\Chrome\Application\chrome.exe
# INFO:choreographer.utils._tmpfile:Temp directory created: C:\Users\HMEUW\AppData\Local\Temp\tmpo3rdhhgc.
# INFO:choreographer.browser_async:Opening browser.
# INFO:choreographer.utils._tmpfile:Temp directory created: C:\Users\HMEUW\AppData\Local\Temp\tmp_p4cvlji.
# INFO:choreographer.browsers.chromium:Temporary directory at: C:\Users\HMEUW\AppData\Local\Temp\tmp_p4cvlji
# DEBUG:browser_proc:[INFO:components\enterprise\browser\controller\chrome_browser_cloud_management_controller.cc:206] No machine level policy manager exists.
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\external_pref_loader.cc:296] You are using an old-style extension deployment method (external_extensions.json), which will soon be deprecated. (see http://developer.chrome.com/docs/extensions/how-to/distribute/install-extensions)
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\external_registry_loader_win.cc:236] Error observing HKLM: Toegang geweigerd. (0x5)
# INFO:kaleido.kaleido:Conforming 1 to file:///C:/Users/HMEUW/AppData/Local/Temp/tmpo3rdhhgc/index.html
# INFO:kaleido.kaleido:Waiting on all navigates
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\forced_extensions\force_installed_metrics.cc:511] All forced extensions seem to be installed
# INFO:kaleido.kaleido:All navigates done, putting them all in queue.
# INFO:kaleido.kaleido:Getting tab from queue (has 1)
# INFO:kaleido.kaleido:Got EA9D
# INFO:kaleido._kaleido_tab:Processing profiel_rondom_dp725__0m_tekening_Deltaversterking_bij_dp7255_50m.png
# INFO:kaleido._kaleido_tab:Sending big command for profiel_rondom_dp725__0m_tekening_Deltaversterking_bij_dp7255_50m.png.
# INFO:kaleido._kaleido_tab:Sent big command for profiel_rondom_dp725__0m_tekening_Deltaversterking_bij_dp7255_50m.png.
# INFO:kaleido.kaleido:Reloading tab EA9D before return.
# INFO:kaleido.kaleido:Putting tab EA9D back (queue size: 0).
# INFO:kaleido.kaleido:Waiting for all cleanups to finish.
# INFO:kaleido.kaleido:Exiting Kaleido
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo

# %% [markdown]
# # Overview for standpipe analysis
#
# Plot sections for all locations with a section or a standpipe

# %%
dp_section = df_section.loc[df_section.region == 'Os', 'dp'].values
dp_section
# Out:
# array([ 725.5,  730.5,  734.5,  736.5,  744.9,  753.1,  754.5,  760.3,
#         763.3,  768.4,  773.4,  777.5,  804.5,  809.4,  812.5,  818.1,
#         829.8,  837.4,  843.5,  846.7,  854.5,  857.3,  863.5,  865. ,
#         868. ,  873.2,  880.8,  886. ,  889.2,  892.5,  898. ,  903.5,
#         908.7,  914. ,  919. ,  922. ,  929. ,  934.9,  940. ,  945. ,
#         950. ,  953. ,  956.8,  961.5,  964. ,  968.8,  971.3,  974. ,
#         977. ,  981. ,  986.2,  996.2, 1001. , 1007. , 1015.3, 1022.4,
#        1026. , 1033.5, 1045.3, 1055.5, 1055.5, 1059. , 1059. , 1066.3,
#        1066.3, 1073.3, 1073.3])

# %%
dp_obs = oc_gwl.loc[oc_gwl.region == 'Os', 'dp'].unique()
dp_obs.sort()
dp_obs
# Out:
# array([ 777.5,  781.5,  783. ,  784.4,  820. ,  854. ,  866. ,  882. ,
#         894. ,  917.1,  930.5,  931.1,  935. ,  941. ,  946. ,  955. ,
#         961. ,  964. ,  970. ,  975. ,  980. ,  982.8,  983. ,  988. ,
#         991. ,  995.8,  996. , 1000. , 1005. , 1010. , 1012. , 1015. ,
#        1020. , 1025. , 1028. , 1029. , 1046. , 1047. , 1052. , 1068. ,
#        1076. ])

# %%
dp_gmw = df_gmw.loc[df_gmw.region == 'Os', 'dp'].unique()
dp_gmw = np.sort(dp_gmw)
dp_gmw
# Out:
# array([ 738.  ,  738.01,  748.99,  749.  ,  761.99,  762.  ,  772.  ,
#         777.5 ,  777.51,  781.63,  781.65,  783.02,  783.11,  784.37,
#         784.43,  789.01,  789.02,  792.99,  793.  ,  796.99,  819.99,
#         853.98,  853.99,  866.03,  866.04,  868.67,  868.75,  869.56,
#         869.93,  882.04,  882.06,  893.95,  894.  ,  917.06,  917.07,
#         917.09,  930.5 ,  931.07,  934.99,  935.02,  940.99,  941.  ,
#         945.99,  955.02,  961.  ,  963.99,  969.95,  969.99,  970.01,
#         970.62,  971.05,  975.  ,  980.  ,  982.79,  982.99,  987.93,
#         987.99,  991.  ,  995.79,  995.99,  997.  , 1000.  , 1000.02,
#        1005.01, 1010.  , 1012.  , 1015.  , 1020.  , 1020.19, 1025.  ,
#        1027.97, 1029.  , 1047.15, 1052.  , 1067.98, 1076.01])

# %%
# create a new list of dp, from dp_gmw, round each item to nearest integer, remove duplicates, remove when values are with 1 unit from each other
dp_gmw_rounded = np.round(dp_gmw).astype(int)
dp_gmw_unique = np.unique(dp_gmw_rounded)
dp_gmw_unique
# Out:
# array([ 738,  749,  762,  772,  778,  782,  783,  784,  789,  793,  797,
#         820,  854,  866,  869,  870,  882,  894,  917,  930,  931,  935,
#         941,  946,  955,  961,  964,  970,  971,  975,  980,  983,  988,
#         991,  996,  997, 1000, 1005, 1010, 1012, 1015, 1020, 1025, 1028,
#        1029, 1047, 1052, 1068, 1076])

# %%
all_dps = []
for dp in [dp_section, dp_obs, dp_gmw]:
    dp = np.round(dp).astype(int)
    dp = np.unique(dp)
    all_dps.append(dp)
# get unique values from all sublists in all_dps
unique_dps = np.unique(np.concatenate(all_dps))
unique_dps
# Out:
# array([ 726,  730,  734,  736,  738,  745,  749,  753,  754,  760,  762,
#         763,  768,  772,  773,  778,  782,  783,  784,  789,  793,  797,
#         804,  809,  812,  818,  820,  830,  837,  844,  847,  854,  857,
#         864,  865,  866,  868,  869,  870,  873,  881,  882,  886,  889,
#         892,  894,  898,  904,  909,  914,  917,  919,  922,  929,  930,
#         931,  935,  940,  941,  945,  946,  950,  953,  955,  957,  961,
#         962,  964,  969,  970,  971,  974,  975,  977,  980,  981,  983,
#         986,  988,  991,  996,  997, 1000, 1001, 1005, 1007, 1010, 1012,
#        1015, 1020, 1022, 1025, 1026, 1028, 1029, 1034, 1045, 1046, 1047,
#        1052, 1056, 1059, 1066, 1068, 1073, 1076])

# %%
# from unique_dps remove values that are within 1 unit from each other
final_dps = []
for dp in unique_dps:
    if len(final_dps) == 0:
        final_dps.append(dp)
    else:
        if dp - final_dps[-1] > 1:
            final_dps.append(dp)
final_dps[:5]
# Out:
# [np.int64(726), np.int64(730), np.int64(734), np.int64(736), np.int64(738)]

# %%
for dp_center in final_dps:
    delta_dp = 2

    fig, fn = gl.create_figure_for_dp(
        dp_center, 
        df_section, 
        geoprofile_cols, 
        df_profile,
        oc_gwl,
        df_gmw=df_gmw,
        delta_dp=delta_dp,
        plot_gwl=True,
        plot_path=PLOT_PATH,
        ylims_upper=[-4, 7],
        auto_open=False,
        )
# Out:
# DEBUG:root:Closest dp with Deltaversterking to 726 is 725.5, fn: es\dsn12_flipped.tif, x_offset: -8
# DEBUG:root:Adding Deltaversterking background from 8\doorsnedes\dsn12_flipped.tif to figure at row 1, col 1.
# DEBUG:root:Plotting column dp 726.6, distance=-23.5211947338196, plotted=[np.float64(-24.0)]
# DEBUG:root:Plotting column dp 727.0, distance=-14.597415089285775, plotted=[np.float64(-24.0), np.float64(-15.0)]
# DEBUG:root:Plotting column dp 727.0, distance=-1.3049853719405646, plotted=[np.float64(-24.0), np.float64(-15.0), np.float64(-1.0)]
# DEBUG:root:Plotting column dp 727.5, distance=-15.691721028034044, plotted=[np.float64(-24.0), np.float64(-15.0), np.float64(-1.0), np.float64(-16.0)]
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# DEBUG:root:Plotting column dp 728.0, distance=-17.463781151908744, plotted=[np.float64(-24.0), np.float64(-15.0), np.float64(-1.0), np.float64(-16.0), np.float64(-17.0)]
# DEBUG:root:Plotting column dp 728.0, distance=-1.6961698947073327, plotted=[np.float64(-24.0), np.float64(-15.0), np.float64(-1.0), np.float64(-16.0), np.float64(-17.0), np.float64(-2.0)]
# DEBUG:root:Closest dp with surface level profile to 726 is 726.0
# WARNING:root:No standpipes to plot in figure. ObsCollection is empty.
# DEBUG:root:gmw worden geplot, aantal: 0
# WARNING:root:No standpipes to plot in figure. ObsCollection is empty.
# DEBUG:asyncio:Using selector: SelectSelector
# INFO:choreographer.browsers.chromium:Chromium init'ed with kwargs {}
# DEBUG:root:Looking for browser, skipping local? False
# DEBUG:root:Looking for at local chrome download path: C:\Users\HMEUW\.conda\envs\wk20260129\Lib\site-packages\choreographer\cli\browser_exe\chrome-win64\chrome.exe
# DEBUG:root:Local chrome not found at path: C:\Users\HMEUW\.conda\envs\wk20260129\Lib\site-packages\choreographer\cli\browser_exe\chrome-win64\chrome.exe.
# INFO:choreographer.browsers.chromium:Found chromium path: C:\Program Files\Google\Chrome\Application\chrome.exe
# INFO:choreographer.utils._tmpfile:Temp directory created: C:\Users\HMEUW\AppData\Local\Temp\tmpi3bp4an_.
# INFO:choreographer.browser_async:Opening browser.
# INFO:choreographer.utils._tmpfile:Temp directory created: C:\Users\HMEUW\AppData\Local\Temp\tmpqtyayowu.
# INFO:choreographer.browsers.chromium:Temporary directory at: C:\Users\HMEUW\AppData\Local\Temp\tmpqtyayowu
# DEBUG:browser_proc:[INFO:components\enterprise\browser\controller\chrome_browser_cloud_management_controller.cc:206] No machine level policy manager exists.
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\external_pref_loader.cc:296] You are using an old-style extension deployment method (external_extensions.json), which will soon be deprecated. (see http://developer.chrome.com/docs/extensions/how-to/distribute/install-extensions)
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\external_registry_loader_win.cc:236] Error observing HKLM: Toegang geweigerd. (0x5)
# INFO:kaleido.kaleido:Conforming 1 to file:///C:/Users/HMEUW/AppData/Local/Temp/tmpi3bp4an_/index.html
# INFO:kaleido.kaleido:Waiting on all navigates
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\forced_extensions\force_installed_metrics.cc:511] All forced extensions seem to be installed
# INFO:kaleido.kaleido:All navigates done, putting them all in queue.
# INFO:kaleido.kaleido:Getting tab from queue (has 1)
# INFO:kaleido.kaleido:Got F81A
# INFO:kaleido._kaleido_tab:Processing profiel_rondom_dp726__200m_tekening_Deltaversterking_bij_dp7255__50m.png
# INFO:kaleido._kaleido_tab:Sending big command for profiel_rondom_dp726__200m_tekening_Deltaversterking_bij_dp7255__50m.png.
# INFO:kaleido._kaleido_tab:Sent big command for profiel_rondom_dp726__200m_tekening_Deltaversterking_bij_dp7255__50m.png.
# INFO:kaleido.kaleido:Reloading tab F81A before return.
# INFO:kaleido.kaleido:Putting tab F81A back (queue size: 0).
# INFO:kaleido.kaleido:Waiting for all cleanups to finish.
# INFO:kaleido.kaleido:Exiting Kaleido
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo
# DEBUG:root:Closest dp with Deltaversterking to 730 is 730.5, fn: es\dsn11_flipped.tif, x_offset: 3
# DEBUG:root:Adding Deltaversterking background from 8\doorsnedes\dsn11_flipped.tif to figure at row 1, col 1.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# DEBUG:root:Plotting column dp 730.0, distance=-17.799141297748125, plotted=[np.float64(-18.0)]
# DEBUG:root:Plotting column dp 730.0, distance=-1.1892118978417905, plotted=[np.float64(-18.0), np.float64(-1.0)]
# DEBUG:root:Plotting column dp 729.5, distance=-18.014394041265408, plotted=[np.float64(-18.0), np.float64(-1.0), np.float64(-19.0)]
# DEBUG:root:Plotting column dp 730.5, distance=-18.06494863489123, plotted=[np.float64(-18.0), np.float64(-1.0), np.float64(-19.0), np.float64(-17.0)]
# DEBUG:root:Plotting column dp 731.0, distance=-18.620118469212205, plotted=[np.float64(-18.0), np.float64(-1.0), np.float64(-19.0), np.float64(-17.0), np.float64(-16.0)]
# DEBUG:root:Plotting column dp 731.0, distance=-1.3451802750354211, plotted=[np.float64(-18.0), np.float64(-1.0), np.float64(-19.0), np.float64(-17.0), np.float64(-16.0), np.float64(0.0)]
# DEBUG:root:Plotting column dp 729.0, distance=-17.801343723128102, plotted=[np.float64(-18.0), np.float64(-1.0), np.float64(-19.0), np.float64(-17.0), np.float64(-16.0), np.float64(0.0), np.float64(-20.0)]
# DEBUG:root:Plotting column dp 729.0, distance=-1.4882019145167444, plotted=[np.float64(-18.0), np.float64(-1.0), np.float64(-19.0), np.float64(-17.0), np.float64(-16.0), np.float64(0.0), np.float64(-20.0), np.float64(-2.0)]
# DEBUG:root:Plotting column dp 731.5, distance=-18.232099961227156, plotted=[np.float64(-18.0), np.float64(-1.0), np.float64(-19.0), np.float64(-17.0), np.float64(-16.0), np.float64(0.0), np.float64(-20.0), np.float64(-2.0), np.float64(-15.0)]
# DEBUG:root:Plotting column dp 728.5, distance=-18.408115046516336, plotted=[np.float64(-18.0), np.float64(-1.0), np.float64(-19.0), np.float64(-17.0), np.float64(-16.0), np.float64(0.0), np.float64(-20.0), np.float64(-2.0), np.float64(-15.0), np.float64(-21.0)]
# DEBUG:root:Plotting column dp 732.0, distance=-17.735228027293264, plotted=[np.float64(-18.0), np.float64(-1.0), np.float64(-19.0), np.float64(-17.0), np.float64(-16.0), np.float64(0.0), np.float64(-20.0), np.float64(-2.0), np.float64(-15.0), np.float64(-21.0), np.float64(-14.0)]
# DEBUG:root:Plotting column dp 732.0, distance=-1.1532654229378643, plotted=[np.float64(-18.0), np.float64(-1.0), np.float64(-19.0), np.float64(-17.0), np.float64(-16.0), np.float64(0.0), np.float64(-20.0), np.float64(-2.0), np.float64(-15.0), np.float64(-21.0), np.float64(-14.0), np.float64(1.0)]
# DEBUG:root:Plotting column dp 728.0, distance=-17.463781151908744, plotted=[np.float64(-18.0), np.float64(-1.0), np.float64(-19.0), np.float64(-17.0), np.float64(-16.0), np.float64(0.0), np.float64(-20.0), np.float64(-2.0), np.float64(-15.0), np.float64(-21.0), np.float64(-14.0), np.float64(1.0), np.float64(-22.0)]
# DEBUG:root:Plotting column dp 728.0, distance=-1.6961698947073327, plotted=[np.float64(-18.0), np.float64(-1.0), np.float64(-19.0), np.float64(-17.0), np.float64(-16.0), np.float64(0.0), np.float64(-20.0), np.float64(-2.0), np.float64(-15.0), np.float64(-21.0), np.float64(-14.0), np.float64(1.0), np.float64(-22.0), np.float64(-3.0)]
# DEBUG:root:Closest dp with surface level profile to 730 is 730.0
# WARNING:root:No standpipes to plot in figure. ObsCollection is empty.
# DEBUG:root:gmw worden geplot, aantal: 0
# WARNING:root:No standpipes to plot in figure. ObsCollection is empty.
# DEBUG:asyncio:Using selector: SelectSelector
# INFO:choreographer.browsers.chromium:Chromium init'ed with kwargs {}
# DEBUG:root:Looking for browser, skipping local? False
# DEBUG:root:Looking for at local chrome download path: C:\Users\HMEUW\.conda\envs\wk20260129\Lib\site-packages\choreographer\cli\browser_exe\chrome-win64\chrome.exe
# DEBUG:root:Local chrome not found at path: C:\Users\HMEUW\.conda\envs\wk20260129\Lib\site-packages\choreographer\cli\browser_exe\chrome-win64\chrome.exe.
# INFO:choreographer.browsers.chromium:Found chromium path: C:\Program Files\Google\Chrome\Application\chrome.exe
# INFO:choreographer.utils._tmpfile:Temp directory created: C:\Users\HMEUW\AppData\Local\Temp\tmph2rqfndf.
# INFO:choreographer.browser_async:Opening browser.
# INFO:choreographer.utils._tmpfile:Temp directory created: C:\Users\HMEUW\AppData\Local\Temp\tmphhu75wfm.
# INFO:choreographer.browsers.chromium:Temporary directory at: C:\Users\HMEUW\AppData\Local\Temp\tmphhu75wfm
# DEBUG:browser_proc:[INFO:components\enterprise\browser\controller\chrome_browser_cloud_management_controller.cc:206] No machine level policy manager exists.
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\external_pref_loader.cc:296] You are using an old-style extension deployment method (external_extensions.json), which will soon be deprecated. (see http://developer.chrome.com/docs/extensions/how-to/distribute/install-extensions)
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\external_registry_loader_win.cc:236] Error observing HKLM: Toegang geweigerd. (0x5)
# INFO:kaleido.kaleido:Conforming 1 to file:///C:/Users/HMEUW/AppData/Local/Temp/tmph2rqfndf/index.html
# INFO:kaleido.kaleido:Waiting on all navigates
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\forced_extensions\force_installed_metrics.cc:511] All forced extensions seem to be installed
# INFO:kaleido.kaleido:All navigates done, putting them all in queue.
# INFO:kaleido.kaleido:Getting tab from queue (has 1)
# INFO:kaleido.kaleido:Got 352B
# INFO:kaleido._kaleido_tab:Processing profiel_rondom_dp730__200m_tekening_Deltaversterking_bij_dp7305_50m.png
# INFO:kaleido._kaleido_tab:Sending big command for profiel_rondom_dp730__200m_tekening_Deltaversterking_bij_dp7305_50m.png.
# INFO:kaleido._kaleido_tab:Sent big command for profiel_rondom_dp730__200m_tekening_Deltaversterking_bij_dp7305_50m.png.
# INFO:kaleido.kaleido:Reloading tab 352B before return.
# INFO:kaleido.kaleido:Putting tab 352B back (queue size: 0).
# INFO:kaleido.kaleido:Waiting for all cleanups to finish.
# INFO:kaleido.kaleido:Exiting Kaleido
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo
# DEBUG:root:Closest dp with Deltaversterking to 734 is 734.5, fn: es\dsn10_flipped.tif, x_offset: 0
# DEBUG:root:Adding Deltaversterking background from 8\doorsnedes\dsn10_flipped.tif to figure at row 1, col 1.
# DEBUG:root:Plotting column dp 734.0, distance=-17.35787311220878, plotted=[np.float64(-17.0)]
# DEBUG:root:Plotting column dp 734.0, distance=-1.3256368910134195, plotted=[np.float64(-17.0), np.float64(-1.0)]
# DEBUG:root:Plotting column dp 734.5, distance=-17.440452026043292, plotted=[np.float64(-17.0), np.float64(-1.0), np.float64(-16.0)]
# DEBUG:root:Plotting column dp 733.4, distance=-17.334309971287446, plotted=[np.float64(-17.0), np.float64(-1.0), np.float64(-16.0), np.float64(-18.0)]
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# DEBUG:root:Plotting column dp 733.0, distance=-18.29927157544049, plotted=[np.float64(-17.0), np.float64(-1.0), np.float64(-16.0), np.float64(-18.0), np.float64(-19.0)]
# DEBUG:root:Plotting column dp 733.0, distance=-1.2644847072818262, plotted=[np.float64(-17.0), np.float64(-1.0), np.float64(-16.0), np.float64(-18.0), np.float64(-19.0), np.float64(-2.0)]
# DEBUG:root:Plotting column dp 735.0, distance=-16.654108074506976, plotted=[np.float64(-17.0), np.float64(-1.0), np.float64(-16.0), np.float64(-18.0), np.float64(-19.0), np.float64(-2.0), np.float64(-15.0)]
# DEBUG:root:Plotting column dp 735.0, distance=-1.7003354138568971, plotted=[np.float64(-17.0), np.float64(-1.0), np.float64(-16.0), np.float64(-18.0), np.float64(-19.0), np.float64(-2.0), np.float64(-15.0), np.float64(0.0)]
# DEBUG:root:Plotting column dp 735.0, distance=7.8639936597818885, plotted=[np.float64(-17.0), np.float64(-1.0), np.float64(-16.0), np.float64(-18.0), np.float64(-19.0), np.float64(-2.0), np.float64(-15.0), np.float64(0.0), np.float64(8.0)]
# DEBUG:root:Plotting column dp 732.5, distance=-18.733223121381823, plotted=[np.float64(-17.0), np.float64(-1.0), np.float64(-16.0), np.float64(-18.0), np.float64(-19.0), np.float64(-2.0), np.float64(-15.0), np.float64(0.0), np.float64(8.0), np.float64(-20.0)]
# DEBUG:root:Plotting column dp 735.5, distance=-15.810118992650587, plotted=[np.float64(-17.0), np.float64(-1.0), np.float64(-16.0), np.float64(-18.0), np.float64(-19.0), np.float64(-2.0), np.float64(-15.0), np.float64(0.0), np.float64(8.0), np.float64(-20.0), np.float64(-14.0)]
# DEBUG:root:Plotting column dp 736.0, distance=-15.484828522744591, plotted=[np.float64(-17.0), np.float64(-1.0), np.float64(-16.0), np.float64(-18.0), np.float64(-19.0), np.float64(-2.0), np.float64(-15.0), np.float64(0.0), np.float64(8.0), np.float64(-20.0), np.float64(-14.0), np.float64(-13.0)]
# DEBUG:root:Plotting column dp 732.0, distance=-17.735228027293264, plotted=[np.float64(-17.0), np.float64(-1.0), np.float64(-16.0), np.float64(-18.0), np.float64(-19.0), np.float64(-2.0), np.float64(-15.0), np.float64(0.0), np.float64(8.0), np.float64(-20.0), np.float64(-14.0), np.float64(-13.0), np.float64(-21.0)]
# DEBUG:root:Plotting column dp 732.0, distance=-1.1532654229378643, plotted=[np.float64(-17.0), np.float64(-1.0), np.float64(-16.0), np.float64(-18.0), np.float64(-19.0), np.float64(-2.0), np.float64(-15.0), np.float64(0.0), np.float64(8.0), np.float64(-20.0), np.float64(-14.0), np.float64(-13.0), np.float64(-21.0), np.float64(-3.0)]
# DEBUG:root:Plotting column dp 736.0, distance=9.711842014264965, plotted=[np.float64(-17.0), np.float64(-1.0), np.float64(-16.0), np.float64(-18.0), np.float64(-19.0), np.float64(-2.0), np.float64(-15.0), np.float64(0.0), np.float64(8.0), np.float64(-20.0), np.float64(-14.0), np.float64(-13.0), np.float64(-21.0), np.float64(-3.0), np.float64(10.0)]
# DEBUG:root:Plotting column dp 736.0, distance=-1.8118043695231467, plotted=[np.float64(-17.0), np.float64(-1.0), np.float64(-16.0), np.float64(-18.0), np.float64(-19.0), np.float64(-2.0), np.float64(-15.0), np.float64(0.0), np.float64(8.0), np.float64(-20.0), np.float64(-14.0), np.float64(-13.0), np.float64(-21.0), np.float64(-3.0), np.float64(10.0), np.float64(1.0)]
# DEBUG:root:Closest dp with surface level profile to 734 is 734.0
# WARNING:root:No standpipes to plot in figure. ObsCollection is empty.
# DEBUG:root:gmw worden geplot, aantal: 0
# WARNING:root:No standpipes to plot in figure. ObsCollection is empty.
# DEBUG:asyncio:Using selector: SelectSelector
# INFO:choreographer.browsers.chromium:Chromium init'ed with kwargs {}
# DEBUG:root:Looking for browser, skipping local? False
# DEBUG:root:Looking for at local chrome download path: C:\Users\HMEUW\.conda\envs\wk20260129\Lib\site-packages\choreographer\cli\browser_exe\chrome-win64\chrome.exe
# DEBUG:root:Local chrome not found at path: C:\Users\HMEUW\.conda\envs\wk20260129\Lib\site-packages\choreographer\cli\browser_exe\chrome-win64\chrome.exe.
# INFO:choreographer.browsers.chromium:Found chromium path: C:\Program Files\Google\Chrome\Application\chrome.exe
# INFO:choreographer.utils._tmpfile:Temp directory created: C:\Users\HMEUW\AppData\Local\Temp\tmph8kggwkx.
# INFO:choreographer.browser_async:Opening browser.
# INFO:choreographer.utils._tmpfile:Temp directory created: C:\Users\HMEUW\AppData\Local\Temp\tmpm12_1ykc.
# INFO:choreographer.browsers.chromium:Temporary directory at: C:\Users\HMEUW\AppData\Local\Temp\tmpm12_1ykc
# DEBUG:browser_proc:[INFO:components\enterprise\browser\controller\chrome_browser_cloud_management_controller.cc:206] No machine level policy manager exists.
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\external_pref_loader.cc:296] You are using an old-style extension deployment method (external_extensions.json), which will soon be deprecated. (see http://developer.chrome.com/docs/extensions/how-to/distribute/install-extensions)
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\external_registry_loader_win.cc:236] Error observing HKLM: Toegang geweigerd. (0x5)
# INFO:kaleido.kaleido:Conforming 1 to file:///C:/Users/HMEUW/AppData/Local/Temp/tmph8kggwkx/index.html
# INFO:kaleido.kaleido:Waiting on all navigates
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\forced_extensions\force_installed_metrics.cc:511] All forced extensions seem to be installed
# INFO:kaleido.kaleido:All navigates done, putting them all in queue.
# INFO:kaleido.kaleido:Getting tab from queue (has 1)
# INFO:kaleido.kaleido:Got CF7A
# INFO:kaleido._kaleido_tab:Processing profiel_rondom_dp734__200m_tekening_Deltaversterking_bij_dp7345_50m.png
# INFO:kaleido._kaleido_tab:Sending big command for profiel_rondom_dp734__200m_tekening_Deltaversterking_bij_dp7345_50m.png.
# INFO:kaleido._kaleido_tab:Sent big command for profiel_rondom_dp734__200m_tekening_Deltaversterking_bij_dp7345_50m.png.
# INFO:kaleido.kaleido:Reloading tab CF7A before return.
# INFO:kaleido.kaleido:Putting tab CF7A back (queue size: 0).
# INFO:kaleido.kaleido:Waiting for all cleanups to finish.
# INFO:kaleido.kaleido:Exiting Kaleido
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo
# DEBUG:root:Closest dp with Deltaversterking to 736 is 736.5, fn: des\dsn9_flipped.tif, x_offset: -5
# DEBUG:root:Adding Deltaversterking background from 78\doorsnedes\dsn9_flipped.tif to figure at row 1, col 1.
# DEBUG:root:Plotting column dp 736.0, distance=-15.484828522744591, plotted=[np.float64(-15.0)]
# DEBUG:root:Plotting column dp 736.0, distance=9.711842014264965, plotted=[np.float64(-15.0), np.float64(10.0)]
# DEBUG:root:Plotting column dp 736.0, distance=-1.8118043695231467, plotted=[np.float64(-15.0), np.float64(10.0), np.float64(-2.0)]
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# DEBUG:root:Plotting column dp 735.5, distance=-15.810118992650587, plotted=[np.float64(-15.0), np.float64(10.0), np.float64(-2.0), np.float64(-16.0)]
# DEBUG:root:Plotting column dp 736.5, distance=-16.379103275277874, plotted=[np.float64(-15.0), np.float64(10.0), np.float64(-2.0), np.float64(-16.0), np.float64(-14.0)]
# DEBUG:root:Plotting column dp 735.0, distance=-16.654108074506976, plotted=[np.float64(-15.0), np.float64(10.0), np.float64(-2.0), np.float64(-16.0), np.float64(-14.0), np.float64(-17.0)]
# DEBUG:root:Plotting column dp 735.0, distance=-1.7003354138568971, plotted=[np.float64(-15.0), np.float64(10.0), np.float64(-2.0), np.float64(-16.0), np.float64(-14.0), np.float64(-17.0), np.float64(-3.0)]
# DEBUG:root:Plotting column dp 737.0, distance=-15.703149688761986, plotted=[np.float64(-15.0), np.float64(10.0), np.float64(-2.0), np.float64(-16.0), np.float64(-14.0), np.float64(-17.0), np.float64(-3.0), np.float64(-13.0)]
# DEBUG:root:Plotting column dp 735.0, distance=7.8639936597818885, plotted=[np.float64(-15.0), np.float64(10.0), np.float64(-2.0), np.float64(-16.0), np.float64(-14.0), np.float64(-17.0), np.float64(-3.0), np.float64(-13.0), np.float64(8.0)]
# DEBUG:root:Plotting column dp 737.0, distance=9.89384848651452, plotted=[np.float64(-15.0), np.float64(10.0), np.float64(-2.0), np.float64(-16.0), np.float64(-14.0), np.float64(-17.0), np.float64(-3.0), np.float64(-13.0), np.float64(8.0), np.float64(11.0)]
# DEBUG:root:Plotting column dp 737.0, distance=-1.2595634748365176, plotted=[np.float64(-15.0), np.float64(10.0), np.float64(-2.0), np.float64(-16.0), np.float64(-14.0), np.float64(-17.0), np.float64(-3.0), np.float64(-13.0), np.float64(8.0), np.float64(11.0), np.float64(-1.0)]
# DEBUG:root:Plotting column dp 734.5, distance=-17.440452026043292, plotted=[np.float64(-15.0), np.float64(10.0), np.float64(-2.0), np.float64(-16.0), np.float64(-14.0), np.float64(-17.0), np.float64(-3.0), np.float64(-13.0), np.float64(8.0), np.float64(11.0), np.float64(-1.0), np.float64(-18.0)]
# DEBUG:root:Plotting column dp 737.5, distance=-16.151261177523427, plotted=[np.float64(-15.0), np.float64(10.0), np.float64(-2.0), np.float64(-16.0), np.float64(-14.0), np.float64(-17.0), np.float64(-3.0), np.float64(-13.0), np.float64(8.0), np.float64(11.0), np.float64(-1.0), np.float64(-18.0), np.float64(-12.0)]
# DEBUG:root:Plotting column dp 734.0, distance=-17.35787311220878, plotted=[np.float64(-15.0), np.float64(10.0), np.float64(-2.0), np.float64(-16.0), np.float64(-14.0), np.float64(-17.0), np.float64(-3.0), np.float64(-13.0), np.float64(8.0), np.float64(11.0), np.float64(-1.0), np.float64(-18.0), np.float64(-12.0), np.float64(-19.0)]
# DEBUG:root:Plotting column dp 734.0, distance=-1.3256368910134195, plotted=[np.float64(-15.0), np.float64(10.0), np.float64(-2.0), np.float64(-16.0), np.float64(-14.0), np.float64(-17.0), np.float64(-3.0), np.float64(-13.0), np.float64(8.0), np.float64(11.0), np.float64(-1.0), np.float64(-18.0), np.float64(-12.0), np.float64(-19.0), np.float64(-4.0)]
# DEBUG:root:Plotting column dp 738.0, distance=-16.392516335839755, plotted=[np.float64(-15.0), np.float64(10.0), np.float64(-2.0), np.float64(-16.0), np.float64(-14.0), np.float64(-17.0), np.float64(-3.0), np.float64(-13.0), np.float64(8.0), np.float64(11.0), np.float64(-1.0), np.float64(-18.0), np.float64(-12.0), np.float64(-19.0), np.float64(-4.0), np.float64(-11.0)]
# DEBUG:root:Plotting column dp 738.0, distance=9.279222057192387, plotted=[np.float64(-15.0), np.float64(10.0), np.float64(-2.0), np.float64(-16.0), np.float64(-14.0), np.float64(-17.0), np.float64(-3.0), np.float64(-13.0), np.float64(8.0), np.float64(11.0), np.float64(-1.0), np.float64(-18.0), np.float64(-12.0), np.float64(-19.0), np.float64(-4.0), np.float64(-11.0), np.float64(9.0)]
# DEBUG:root:Plotting column dp 738.0, distance=-1.4045167713055517, plotted=[np.float64(-15.0), np.float64(10.0), np.float64(-2.0), np.float64(-16.0), np.float64(-14.0), np.float64(-17.0), np.float64(-3.0), np.float64(-13.0), np.float64(8.0), np.float64(11.0), np.float64(-1.0), np.float64(-18.0), np.float64(-12.0), np.float64(-19.0), np.float64(-4.0), np.float64(-11.0), np.float64(9.0), np.float64(0.0)]
# DEBUG:root:Closest dp with surface level profile to 736 is 736.0
# WARNING:root:No standpipes to plot in figure. ObsCollection is empty.
# DEBUG:root:gmw worden geplot, aantal: 3
# INFO:root:Plotting 3 standpipes in figure, method=by_dp_marker.
# c:\data\python\cloned\geolookup\docs\examples\..\..\geolookup\functions.py:773: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# DEBUG:asyncio:Using selector: SelectSelector
# INFO:choreographer.browsers.chromium:Chromium init'ed with kwargs {}
# DEBUG:root:Looking for browser, skipping local? False
# DEBUG:root:Looking for at local chrome download path: C:\Users\HMEUW\.conda\envs\wk20260129\Lib\site-packages\choreographer\cli\browser_exe\chrome-win64\chrome.exe
# DEBUG:root:Local chrome not found at path: C:\Users\HMEUW\.conda\envs\wk20260129\Lib\site-packages\choreographer\cli\browser_exe\chrome-win64\chrome.exe.
# INFO:choreographer.browsers.chromium:Found chromium path: C:\Program Files\Google\Chrome\Application\chrome.exe
# INFO:choreographer.utils._tmpfile:Temp directory created: C:\Users\HMEUW\AppData\Local\Temp\tmpvuo0f6w6.
# INFO:choreographer.browser_async:Opening browser.
# INFO:choreographer.utils._tmpfile:Temp directory created: C:\Users\HMEUW\AppData\Local\Temp\tmpb3jyee0a.
# INFO:choreographer.browsers.chromium:Temporary directory at: C:\Users\HMEUW\AppData\Local\Temp\tmpb3jyee0a
# DEBUG:browser_proc:[INFO:components\enterprise\browser\controller\chrome_browser_cloud_management_controller.cc:206] No machine level policy manager exists.
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\external_pref_loader.cc:296] You are using an old-style extension deployment method (external_extensions.json), which will soon be deprecated. (see http://developer.chrome.com/docs/extensions/how-to/distribute/install-extensions)
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\external_registry_loader_win.cc:236] Error observing HKLM: Toegang geweigerd. (0x5)
# INFO:kaleido.kaleido:Conforming 1 to file:///C:/Users/HMEUW/AppData/Local/Temp/tmpvuo0f6w6/index.html
# INFO:kaleido.kaleido:Waiting on all navigates
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\forced_extensions\force_installed_metrics.cc:511] All forced extensions seem to be installed
# INFO:kaleido.kaleido:All navigates done, putting them all in queue.
# INFO:kaleido.kaleido:Getting tab from queue (has 1)
# INFO:kaleido.kaleido:Got B03D
# INFO:kaleido._kaleido_tab:Processing profiel_rondom_dp736__200m_tekening_Deltaversterking_bij_dp7365_50m.png
# INFO:kaleido._kaleido_tab:Sending big command for profiel_rondom_dp736__200m_tekening_Deltaversterking_bij_dp7365_50m.png.
# INFO:kaleido._kaleido_tab:Sent big command for profiel_rondom_dp736__200m_tekening_Deltaversterking_bij_dp7365_50m.png.
# INFO:kaleido.kaleido:Reloading tab B03D before return.
# INFO:kaleido.kaleido:Putting tab B03D back (queue size: 0).
# INFO:kaleido.kaleido:Waiting for all cleanups to finish.
# INFO:kaleido.kaleido:Exiting Kaleido
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo
# DEBUG:root:Closest dp with Deltaversterking to 738 is 736.5, fn: des\dsn9_flipped.tif, x_offset: -5
# DEBUG:root:Adding Deltaversterking background from 78\doorsnedes\dsn9_flipped.tif to figure at row 1, col 1.
# DEBUG:root:Plotting column dp 738.0, distance=-16.392516335839755, plotted=[np.float64(-16.0)]
# DEBUG:root:Plotting column dp 738.0, distance=9.279222057192387, plotted=[np.float64(-16.0), np.float64(9.0)]
# DEBUG:root:Plotting column dp 738.0, distance=-1.4045167713055517, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0)]
# DEBUG:root:Plotting column dp 737.5, distance=-16.151261177523427, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0)]
# DEBUG:root:Plotting column dp 738.5, distance=-16.48225691616399, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0)]
# DEBUG:root:Plotting column dp 737.0, distance=-15.703149688761986, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0)]
# DEBUG:root:Plotting column dp 737.0, distance=9.89384848651452, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(10.0)]
# DEBUG:root:Plotting column dp 737.0, distance=-1.2595634748365176, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(10.0), np.float64(-2.0)]
# DEBUG:root:Plotting column dp 739.0, distance=-1.1599358124481596, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(10.0), np.float64(-2.0), np.float64(0.0)]
# DEBUG:root:Plotting column dp 739.0, distance=-17.181994471721463, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(10.0), np.float64(-2.0), np.float64(0.0), np.float64(-14.0)]
# DEBUG:root:Plotting column dp 739.0, distance=9.356033045243688, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(10.0), np.float64(-2.0), np.float64(0.0), np.float64(-14.0), np.float64(11.0)]
# DEBUG:root:Plotting column dp 736.5, distance=-16.379103275277874, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(10.0), np.float64(-2.0), np.float64(0.0), np.float64(-14.0), np.float64(11.0), np.float64(-19.0)]
# DEBUG:root:Plotting column dp 739.5, distance=-15.577034286695794, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(10.0), np.float64(-2.0), np.float64(0.0), np.float64(-14.0), np.float64(11.0), np.float64(-19.0), np.float64(-13.0)]
# DEBUG:root:Plotting column dp 736.0, distance=-15.484828522744591, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(10.0), np.float64(-2.0), np.float64(0.0), np.float64(-14.0), np.float64(11.0), np.float64(-19.0), np.float64(-13.0), np.float64(-20.0)]
# DEBUG:root:Plotting column dp 736.0, distance=9.711842014264965, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(10.0), np.float64(-2.0), np.float64(0.0), np.float64(-14.0), np.float64(11.0), np.float64(-19.0), np.float64(-13.0), np.float64(-20.0), np.float64(8.0)]
# DEBUG:root:Plotting column dp 736.0, distance=-1.8118043695231467, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(10.0), np.float64(-2.0), np.float64(0.0), np.float64(-14.0), np.float64(11.0), np.float64(-19.0), np.float64(-13.0), np.float64(-20.0), np.float64(8.0), np.float64(-3.0)]
# DEBUG:root:Plotting column dp 740.0, distance=-15.113563523678662, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(10.0), np.float64(-2.0), np.float64(0.0), np.float64(-14.0), np.float64(11.0), np.float64(-19.0), np.float64(-13.0), np.float64(-20.0), np.float64(8.0), np.float64(-3.0), np.float64(-12.0)]
# DEBUG:root:Plotting column dp 740.0, distance=16.667431426128886, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(10.0), np.float64(-2.0), np.float64(0.0), np.float64(-14.0), np.float64(11.0), np.float64(-19.0), np.float64(-13.0), np.float64(-20.0), np.float64(8.0), np.float64(-3.0), np.float64(-12.0), np.float64(17.0)]
# DEBUG:root:Plotting column dp 740.0, distance=-1.489486523882994, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(10.0), np.float64(-2.0), np.float64(0.0), np.float64(-14.0), np.float64(11.0), np.float64(-19.0), np.float64(-13.0), np.float64(-20.0), np.float64(8.0), np.float64(-3.0), np.float64(-12.0), np.float64(17.0), np.float64(1.0)]
# DEBUG:root:Closest dp with surface level profile to 738 is 738.0
# WARNING:root:No standpipes to plot in figure. ObsCollection is empty.
# DEBUG:root:gmw worden geplot, aantal: 4
# INFO:root:Plotting 4 standpipes in figure, method=by_dp_marker.
# c:\data\python\cloned\geolookup\docs\examples\..\..\geolookup\functions.py:773: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# DEBUG:asyncio:Using selector: SelectSelector
# INFO:choreographer.browsers.chromium:Chromium init'ed with kwargs {}
# DEBUG:root:Looking for browser, skipping local? False
# DEBUG:root:Looking for at local chrome download path: C:\Users\HMEUW\.conda\envs\wk20260129\Lib\site-packages\choreographer\cli\browser_exe\chrome-win64\chrome.exe
# DEBUG:root:Local chrome not found at path: C:\Users\HMEUW\.conda\envs\wk20260129\Lib\site-packages\choreographer\cli\browser_exe\chrome-win64\chrome.exe.
# INFO:choreographer.browsers.chromium:Found chromium path: C:\Program Files\Google\Chrome\Application\chrome.exe
# INFO:choreographer.utils._tmpfile:Temp directory created: C:\Users\HMEUW\AppData\Local\Temp\tmp982y9txw.
# INFO:choreographer.browser_async:Opening browser.
# INFO:choreographer.utils._tmpfile:Temp directory created: C:\Users\HMEUW\AppData\Local\Temp\tmp7gmbepvn.
# INFO:choreographer.browsers.chromium:Temporary directory at: C:\Users\HMEUW\AppData\Local\Temp\tmp7gmbepvn
# DEBUG:browser_proc:[INFO:components\enterprise\browser\controller\chrome_browser_cloud_management_controller.cc:206] No machine level policy manager exists.
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\external_pref_loader.cc:296] You are using an old-style extension deployment method (external_extensions.json), which will soon be deprecated. (see http://developer.chrome.com/docs/extensions/how-to/distribute/install-extensions)
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\external_registry_loader_win.cc:236] Error observing HKLM: Toegang geweigerd. (0x5)
# INFO:kaleido.kaleido:Conforming 1 to file:///C:/Users/HMEUW/AppData/Local/Temp/tmp982y9txw/index.html
# INFO:kaleido.kaleido:Waiting on all navigates
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\forced_extensions\force_installed_metrics.cc:511] All forced extensions seem to be installed
# INFO:kaleido.kaleido:All navigates done, putting them all in queue.
# INFO:kaleido.kaleido:Getting tab from queue (has 1)
# INFO:kaleido.kaleido:Got 7971
# INFO:kaleido._kaleido_tab:Processing profiel_rondom_dp738__200m_tekening_Deltaversterking_bij_dp7365__150m.png
# INFO:kaleido._kaleido_tab:Sending big command for profiel_rondom_dp738__200m_tekening_Deltaversterking_bij_dp7365__150m.png.
# INFO:kaleido._kaleido_tab:Sent big command for profiel_rondom_dp738__200m_tekening_Deltaversterking_bij_dp7365__150m.png.
# INFO:kaleido.kaleido:Reloading tab 7971 before return.
# INFO:kaleido.kaleido:Putting tab 7971 back (queue size: 0).
# INFO:kaleido.kaleido:Waiting for all cleanups to finish.
# INFO:kaleido.kaleido:Exiting Kaleido
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo
# DEBUG:root:Closest dp with Deltaversterking to 745 is 744.9, fn: des\dsn8_flipped.tif, x_offset: -6
# DEBUG:root:Adding Deltaversterking background from 78\doorsnedes\dsn8_flipped.tif to figure at row 1, col 1.
# DEBUG:root:Plotting column dp 745.0, distance=-16.00829058631328, plotted=[np.float64(-16.0)]
# DEBUG:root:Plotting column dp 745.0, distance=8.556940539327755, plotted=[np.float64(-16.0), np.float64(9.0)]
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# DEBUG:root:Plotting column dp 745.0, distance=-1.0690180879534568, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0)]
# DEBUG:root:Plotting column dp 744.5, distance=-15.589501063402894, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0)]
# DEBUG:root:Plotting column dp 745.5, distance=-16.28604727742695, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0)]
# DEBUG:root:Plotting column dp 744.0, distance=-15.757694109159956, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0)]
# DEBUG:root:Plotting column dp 744.0, distance=8.96900364406871, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(8.0)]
# DEBUG:root:Plotting column dp 744.0, distance=-1.196779106833728, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(8.0), np.float64(-2.0)]
# DEBUG:root:Plotting column dp 746.0, distance=-16.438282442045526, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(8.0), np.float64(-2.0), np.float64(-14.0)]
# DEBUG:root:Plotting column dp 746.0, distance=8.489992494359797, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(8.0), np.float64(-2.0), np.float64(-14.0), np.float64(10.0)]
# DEBUG:root:Plotting column dp 746.0, distance=-1.4675376375557898, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(8.0), np.float64(-2.0), np.float64(-14.0), np.float64(10.0), np.float64(0.0)]
# DEBUG:root:Plotting column dp 743.5, distance=-15.704363800827675, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(8.0), np.float64(-2.0), np.float64(-14.0), np.float64(10.0), np.float64(0.0), np.float64(-19.0)]
# DEBUG:root:Plotting column dp 746.5, distance=-15.989353400856473, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(8.0), np.float64(-2.0), np.float64(-14.0), np.float64(10.0), np.float64(0.0), np.float64(-19.0), np.float64(-13.0)]
# DEBUG:root:Plotting column dp 743.0, distance=-15.407998170880154, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(8.0), np.float64(-2.0), np.float64(-14.0), np.float64(10.0), np.float64(0.0), np.float64(-19.0), np.float64(-13.0), np.float64(-20.0)]
# DEBUG:root:Plotting column dp 743.0, distance=8.766330501986554, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(8.0), np.float64(-2.0), np.float64(-14.0), np.float64(10.0), np.float64(0.0), np.float64(-19.0), np.float64(-13.0), np.float64(-20.0), np.float64(7.0)]
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# DEBUG:root:Plotting column dp 743.0, distance=-1.2841322949839586, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(8.0), np.float64(-2.0), np.float64(-14.0), np.float64(10.0), np.float64(0.0), np.float64(-19.0), np.float64(-13.0), np.float64(-20.0), np.float64(7.0), np.float64(-3.0)]
# DEBUG:root:Plotting column dp 747.0, distance=-16.426685068377072, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(8.0), np.float64(-2.0), np.float64(-14.0), np.float64(10.0), np.float64(0.0), np.float64(-19.0), np.float64(-13.0), np.float64(-20.0), np.float64(7.0), np.float64(-3.0), np.float64(-12.0)]
# DEBUG:root:Plotting column dp 747.0, distance=8.315079784318955, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(8.0), np.float64(-2.0), np.float64(-14.0), np.float64(10.0), np.float64(0.0), np.float64(-19.0), np.float64(-13.0), np.float64(-20.0), np.float64(7.0), np.float64(-3.0), np.float64(-12.0), np.float64(11.0)]
# DEBUG:root:Plotting column dp 747.0, distance=-1.4103940118839164, plotted=[np.float64(-16.0), np.float64(9.0), np.float64(-1.0), np.float64(-17.0), np.float64(-15.0), np.float64(-18.0), np.float64(8.0), np.float64(-2.0), np.float64(-14.0), np.float64(10.0), np.float64(0.0), np.float64(-19.0), np.float64(-13.0), np.float64(-20.0), np.float64(7.0), np.float64(-3.0), np.float64(-12.0), np.float64(11.0), np.float64(1.0)]
# DEBUG:root:Closest dp with surface level profile to 745 is 745.0
# WARNING:root:No standpipes to plot in figure. ObsCollection is empty.
# DEBUG:root:gmw worden geplot, aantal: 0
# WARNING:root:No standpipes to plot in figure. ObsCollection is empty.
# DEBUG:asyncio:Using selector: SelectSelector
# INFO:choreographer.browsers.chromium:Chromium init'ed with kwargs {}
# DEBUG:root:Looking for browser, skipping local? False
# DEBUG:root:Looking for at local chrome download path: C:\Users\HMEUW\.conda\envs\wk20260129\Lib\site-packages\choreographer\cli\browser_exe\chrome-win64\chrome.exe
# DEBUG:root:Local chrome not found at path: C:\Users\HMEUW\.conda\envs\wk20260129\Lib\site-packages\choreographer\cli\browser_exe\chrome-win64\chrome.exe.
# INFO:choreographer.browsers.chromium:Found chromium path: C:\Program Files\Google\Chrome\Application\chrome.exe
# INFO:choreographer.utils._tmpfile:Temp directory created: C:\Users\HMEUW\AppData\Local\Temp\tmpsyud7f1i.
# INFO:choreographer.browser_async:Opening browser.
# INFO:choreographer.utils._tmpfile:Temp directory created: C:\Users\HMEUW\AppData\Local\Temp\tmpyksumfux.
# INFO:choreographer.browsers.chromium:Temporary directory at: C:\Users\HMEUW\AppData\Local\Temp\tmpyksumfux
# DEBUG:browser_proc:[INFO:components\enterprise\browser\controller\chrome_browser_cloud_management_controller.cc:206] No machine level policy manager exists.
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\external_pref_loader.cc:296] You are using an old-style extension deployment method (external_extensions.json), which will soon be deprecated. (see http://developer.chrome.com/docs/extensions/how-to/distribute/install-extensions)
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\external_registry_loader_win.cc:236] Error observing HKLM: Toegang geweigerd. (0x5)
# INFO:kaleido.kaleido:Conforming 1 to file:///C:/Users/HMEUW/AppData/Local/Temp/tmpsyud7f1i/index.html
# INFO:kaleido.kaleido:Waiting on all navigates
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\forced_extensions\force_installed_metrics.cc:511] All forced extensions seem to be installed
# INFO:kaleido.kaleido:All navigates done, putting them all in queue.
# INFO:kaleido.kaleido:Getting tab from queue (has 1)
# INFO:kaleido.kaleido:Got 85F3
# INFO:kaleido._kaleido_tab:Processing profiel_rondom_dp745__200m_tekening_Deltaversterking_bij_dp7449__10m.png
# INFO:kaleido._kaleido_tab:Sending big command for profiel_rondom_dp745__200m_tekening_Deltaversterking_bij_dp7449__10m.png.
# INFO:kaleido._kaleido_tab:Sent big command for profiel_rondom_dp745__200m_tekening_Deltaversterking_bij_dp7449__10m.png.
# INFO:kaleido.kaleido:Reloading tab 85F3 before return.
# INFO:kaleido.kaleido:Putting tab 85F3 back (queue size: 0).
# INFO:kaleido.kaleido:Waiting for all cleanups to finish.
# INFO:kaleido.kaleido:Exiting Kaleido
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo
# DEBUG:root:Closest dp with Deltaversterking to 749 is 753.1, fn: des\dsn7_flipped.tif, x_offset: -5
# DEBUG:root:Adding Deltaversterking background from 78\doorsnedes\dsn7_flipped.tif to figure at row 1, col 1.
# DEBUG:root:Plotting column dp 749.0, distance=-1.293797777107387, plotted=[np.float64(-1.0)]
# DEBUG:root:Plotting column dp 749.0, distance=-16.58693230760384, plotted=[np.float64(-1.0), np.float64(-17.0)]
# DEBUG:root:Plotting column dp 749.0, distance=8.630320220281309, plotted=[np.float64(-1.0), np.float64(-17.0), np.float64(9.0)]
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# DEBUG:root:Plotting column dp 748.5, distance=-16.584539371861585, plotted=[np.float64(-1.0), np.float64(-17.0), np.float64(9.0), np.float64(-18.0)]
# DEBUG:root:Plotting column dp 749.5, distance=-16.11138942642884, plotted=[np.float64(-1.0), np.float64(-17.0), np.float64(9.0), np.float64(-18.0), np.float64(-16.0)]
# DEBUG:root:Plotting column dp 748.0, distance=-16.572207385593092, plotted=[np.float64(-1.0), np.float64(-17.0), np.float64(9.0), np.float64(-18.0), np.float64(-16.0), np.float64(-19.0)]
# DEBUG:root:Plotting column dp 750.0, distance=-16.35987217381672, plotted=[np.float64(-1.0), np.float64(-17.0), np.float64(9.0), np.float64(-18.0), np.float64(-16.0), np.float64(-19.0), np.float64(-15.0)]
# DEBUG:root:Plotting column dp 750.0, distance=9.017628062682938, plotted=[np.float64(-1.0), np.float64(-17.0), np.float64(9.0), np.float64(-18.0), np.float64(-16.0), np.float64(-19.0), np.float64(-15.0), np.float64(10.0)]
# DEBUG:root:Plotting column dp 750.0, distance=-1.271892357302947, plotted=[np.float64(-1.0), np.float64(-17.0), np.float64(9.0), np.float64(-18.0), np.float64(-16.0), np.float64(-19.0), np.float64(-15.0), np.float64(10.0), np.float64(0.0)]
# DEBUG:root:Plotting column dp 748.0, distance=8.78509150741042, plotted=[np.float64(-1.0), np.float64(-17.0), np.float64(9.0), np.float64(-18.0), np.float64(-16.0), np.float64(-19.0), np.float64(-15.0), np.float64(10.0), np.float64(0.0), np.float64(8.0)]
# DEBUG:root:Plotting column dp 748.0, distance=-1.4260949575120208, plotted=[np.float64(-1.0), np.float64(-17.0), np.float64(9.0), np.float64(-18.0), np.float64(-16.0), np.float64(-19.0), np.float64(-15.0), np.float64(10.0), np.float64(0.0), np.float64(8.0), np.float64(-2.0)]
# DEBUG:root:Plotting column dp 747.5, distance=-16.61881535170433, plotted=[np.float64(-1.0), np.float64(-17.0), np.float64(9.0), np.float64(-18.0), np.float64(-16.0), np.float64(-19.0), np.float64(-15.0), np.float64(10.0), np.float64(0.0), np.float64(8.0), np.float64(-2.0), np.float64(-20.0)]
# ...
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\forced_extensions\force_installed_metrics.cc:511] All forced extensions seem to be installed
# INFO:kaleido.kaleido:All navigates done, putting them all in queue.
# INFO:kaleido.kaleido:Getting tab from queue (has 1)
# INFO:kaleido.kaleido:Got 89CA
# INFO:kaleido._kaleido_tab:Processing profiel_rondom_dp1068__200m_tekening_Deltaversterking_bij_dp10663__170m.png
# INFO:kaleido._kaleido_tab:Sending big command for profiel_rondom_dp1068__200m_tekening_Deltaversterking_bij_dp10663__170m.png.
# INFO:kaleido._kaleido_tab:Sent big command for profiel_rondom_dp1068__200m_tekening_Deltaversterking_bij_dp10663__170m.png.
# INFO:kaleido.kaleido:Reloading tab 89CA before return.
# INFO:kaleido.kaleido:Putting tab 89CA back (queue size: 0).
# INFO:kaleido.kaleido:Waiting for all cleanups to finish.
# INFO:kaleido.kaleido:Exiting Kaleido
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# DEBUG:root:Closest dp with Deltaversterking to 1073 is 1073.3, fn: des\dsn5_flipped.tif, x_offset: 0
# DEBUG:root:Adding Deltaversterking background from 80\doorsnedes\dsn5_flipped.tif to figure at row 1, col 1.
# DEBUG:root:Plotting column dp 1073.0, distance=-1.524273413729256, plotted=[np.float64(-2.0)]
# DEBUG:root:Plotting column dp 1073.0, distance=-55.58100737041823, plotted=[np.float64(-2.0), np.float64(-56.0)]
# DEBUG:root:Plotting column dp 1072.5, distance=-18.499549553522705, plotted=[np.float64(-2.0), np.float64(-56.0), np.float64(-18.0)]
# DEBUG:root:Plotting column dp 1073.5, distance=-20.534277256350343, plotted=[np.float64(-2.0), np.float64(-56.0), np.float64(-18.0), np.float64(-21.0)]
# DEBUG:root:Plotting column dp 1072.0, distance=-1.7380004485646616, plotted=[np.float64(-2.0), np.float64(-56.0), np.float64(-18.0), np.float64(-21.0), np.float64(-3.0)]
# DEBUG:root:Plotting column dp 1074.0, distance=-53.90228560964085, plotted=[np.float64(-2.0), np.float64(-56.0), np.float64(-18.0), np.float64(-21.0), np.float64(-3.0), np.float64(-54.0)]
# DEBUG:root:Plotting column dp 1074.0, distance=-1.5348410441508302, plotted=[np.float64(-2.0), np.float64(-56.0), np.float64(-18.0), np.float64(-21.0), np.float64(-3.0), np.float64(-54.0), np.float64(-1.0)]
# DEBUG:root:Plotting column dp 1072.0, distance=-56.13422103830555, plotted=[np.float64(-2.0), np.float64(-56.0), np.float64(-18.0), np.float64(-21.0), np.float64(-3.0), np.float64(-54.0), np.float64(-1.0), np.float64(-57.0)]
# DEBUG:root:Plotting column dp 1074.5, distance=-18.517132384796586, plotted=[np.float64(-2.0), np.float64(-56.0), np.float64(-18.0), np.float64(-21.0), np.float64(-3.0), np.float64(-54.0), np.float64(-1.0), np.float64(-57.0), np.float64(-19.0)]
# DEBUG:root:Plotting column dp 1071.5, distance=-19.107911277727226, plotted=[np.float64(-2.0), np.float64(-56.0), np.float64(-18.0), np.float64(-21.0), np.float64(-3.0), np.float64(-54.0), np.float64(-1.0), np.float64(-57.0), np.float64(-19.0), np.float64(-20.0)]
# DEBUG:root:Plotting column dp 1071.0, distance=7.807947543615624, plotted=[np.float64(-2.0), np.float64(-56.0), np.float64(-18.0), np.float64(-21.0), np.float64(-3.0), np.float64(-54.0), np.float64(-1.0), np.float64(-57.0), np.float64(-19.0), np.float64(-20.0), np.float64(8.0)]
# DEBUG:root:Plotting column dp 1075.0, distance=-54.78041172224144, plotted=[np.float64(-2.0), np.float64(-56.0), np.float64(-18.0), np.float64(-21.0), np.float64(-3.0), np.float64(-54.0), np.float64(-1.0), np.float64(-57.0), np.float64(-19.0), np.float64(-20.0), np.float64(8.0), np.float64(-55.0)]
# DEBUG:root:Plotting column dp 1071.0, distance=-2.105871386727749, plotted=[np.float64(-2.0), np.float64(-56.0), np.float64(-18.0), np.float64(-21.0), np.float64(-3.0), np.float64(-54.0), np.float64(-1.0), np.float64(-57.0), np.float64(-19.0), np.float64(-20.0), np.float64(8.0), np.float64(-55.0), np.float64(-4.0)]
# DEBUG:root:Plotting column dp 1075.0, distance=-1.3995584500803504, plotted=[np.float64(-2.0), np.float64(-56.0), np.float64(-18.0), np.float64(-21.0), np.float64(-3.0), np.float64(-54.0), np.float64(-1.0), np.float64(-57.0), np.float64(-19.0), np.float64(-20.0), np.float64(8.0), np.float64(-55.0), np.float64(-4.0), np.float64(0.0)]
# DEBUG:root:Plotting column dp 1071.0, distance=-54.65909759490894, plotted=[np.float64(-2.0), np.float64(-56.0), np.float64(-18.0), np.float64(-21.0), np.float64(-3.0), np.float64(-54.0), np.float64(-1.0), np.float64(-57.0), np.float64(-19.0), np.float64(-20.0), np.float64(8.0), np.float64(-55.0), np.float64(-4.0), np.float64(0.0), np.float64(-58.0)]
# DEBUG:root:Closest dp with surface level profile to 1073 is 1073.0
# WARNING:root:No standpipes to plot in figure. ObsCollection is empty.
# DEBUG:root:gmw worden geplot, aantal: 0
# WARNING:root:No standpipes to plot in figure. ObsCollection is empty.
# DEBUG:asyncio:Using selector: SelectSelector
# INFO:choreographer.browsers.chromium:Chromium init'ed with kwargs {}
# DEBUG:root:Looking for browser, skipping local? False
# DEBUG:root:Looking for at local chrome download path: C:\Users\HMEUW\.conda\envs\wk20260129\Lib\site-packages\choreographer\cli\browser_exe\chrome-win64\chrome.exe
# DEBUG:root:Local chrome not found at path: C:\Users\HMEUW\.conda\envs\wk20260129\Lib\site-packages\choreographer\cli\browser_exe\chrome-win64\chrome.exe.
# INFO:choreographer.browsers.chromium:Found chromium path: C:\Program Files\Google\Chrome\Application\chrome.exe
# INFO:choreographer.utils._tmpfile:Temp directory created: C:\Users\HMEUW\AppData\Local\Temp\tmp2lqng7qb.
# INFO:choreographer.browser_async:Opening browser.
# INFO:choreographer.utils._tmpfile:Temp directory created: C:\Users\HMEUW\AppData\Local\Temp\tmpgs3rulv4.
# INFO:choreographer.browsers.chromium:Temporary directory at: C:\Users\HMEUW\AppData\Local\Temp\tmpgs3rulv4
# DEBUG:browser_proc:[INFO:components\enterprise\browser\controller\chrome_browser_cloud_management_controller.cc:206] No machine level policy manager exists.
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\external_pref_loader.cc:296] You are using an old-style extension deployment method (external_extensions.json), which will soon be deprecated. (see http://developer.chrome.com/docs/extensions/how-to/distribute/install-extensions)
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\external_registry_loader_win.cc:236] Error observing HKLM: Toegang geweigerd. (0x5)
# INFO:kaleido.kaleido:Conforming 1 to file:///C:/Users/HMEUW/AppData/Local/Temp/tmp2lqng7qb/index.html
# INFO:kaleido.kaleido:Waiting on all navigates
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\forced_extensions\force_installed_metrics.cc:511] All forced extensions seem to be installed
# INFO:kaleido.kaleido:All navigates done, putting them all in queue.
# INFO:kaleido.kaleido:Getting tab from queue (has 1)
# INFO:kaleido.kaleido:Got 053B
# INFO:kaleido._kaleido_tab:Processing profiel_rondom_dp1073__200m_tekening_Deltaversterking_bij_dp10733_30m.png
# INFO:kaleido._kaleido_tab:Sending big command for profiel_rondom_dp1073__200m_tekening_Deltaversterking_bij_dp10733_30m.png.
# INFO:kaleido._kaleido_tab:Sent big command for profiel_rondom_dp1073__200m_tekening_Deltaversterking_bij_dp10733_30m.png.
# INFO:kaleido.kaleido:Reloading tab 053B before return.
# INFO:kaleido.kaleido:Putting tab 053B back (queue size: 0).
# INFO:kaleido.kaleido:Waiting for all cleanups to finish.
# INFO:kaleido.kaleido:Exiting Kaleido
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo
# DEBUG:root:Closest dp with Deltaversterking to 1076 is 1073.3, fn: des\dsn5_flipped.tif, x_offset: 0
# DEBUG:root:Adding Deltaversterking background from 80\doorsnedes\dsn5_flipped.tif to figure at row 1, col 1.
# DEBUG:root:Plotting column dp 1076.0, distance=-43.39676281913344, plotted=[np.float64(-43.0)]
# DEBUG:root:Plotting column dp 1076.0, distance=-1.1815320401488085, plotted=[np.float64(-43.0), np.float64(-1.0)]
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# DEBUG:root:Plotting column dp 1076.4, distance=-20.01232820062281, plotted=[np.float64(-43.0), np.float64(-1.0), np.float64(-20.0)]
# DEBUG:root:Plotting column dp 1075.5, distance=-15.971280009162262, plotted=[np.float64(-43.0), np.float64(-1.0), np.float64(-20.0), np.float64(-16.0)]
# DEBUG:root:Plotting column dp 1075.0, distance=-54.78041172224144, plotted=[np.float64(-43.0), np.float64(-1.0), np.float64(-20.0), np.float64(-16.0), np.float64(-55.0)]
# DEBUG:root:Plotting column dp 1075.0, distance=-1.3995584500803504, plotted=[np.float64(-43.0), np.float64(-1.0), np.float64(-20.0), np.float64(-16.0), np.float64(-55.0), np.float64(-2.0)]
# DEBUG:root:Plotting column dp 1077.0, distance=-46.47743900495795, plotted=[np.float64(-43.0), np.float64(-1.0), np.float64(-20.0), np.float64(-16.0), np.float64(-55.0), np.float64(-2.0), np.float64(-46.0)]
# DEBUG:root:Plotting column dp 1077.0, distance=-1.0255316259090812, plotted=[np.float64(-43.0), np.float64(-1.0), np.float64(-20.0), np.float64(-16.0), np.float64(-55.0), np.float64(-2.0), np.float64(-46.0), np.float64(0.0)]
# DEBUG:root:Plotting column dp 1074.5, distance=-18.517132384796586, plotted=[np.float64(-43.0), np.float64(-1.0), np.float64(-20.0), np.float64(-16.0), np.float64(-55.0), np.float64(-2.0), np.float64(-46.0), np.float64(0.0), np.float64(-19.0)]
# DEBUG:root:Plotting column dp 1077.5, distance=-42.978860382868085, plotted=[np.float64(-43.0), np.float64(-1.0), np.float64(-20.0), np.float64(-16.0), np.float64(-55.0), np.float64(-2.0), np.float64(-46.0), np.float64(0.0), np.float64(-19.0), np.float64(-42.0)]
# DEBUG:root:Plotting column dp 1074.0, distance=-53.90228560964085, plotted=[np.float64(-43.0), np.float64(-1.0), np.float64(-20.0), np.float64(-16.0), np.float64(-55.0), np.float64(-2.0), np.float64(-46.0), np.float64(0.0), np.float64(-19.0), np.float64(-42.0), np.float64(-54.0)]
# DEBUG:root:Plotting column dp 1078.0, distance=-37.06640728365829, plotted=[np.float64(-43.0), np.float64(-1.0), np.float64(-20.0), np.float64(-16.0), np.float64(-55.0), np.float64(-2.0), np.float64(-46.0), np.float64(0.0), np.float64(-19.0), np.float64(-42.0), np.float64(-54.0), np.float64(-37.0)]
# DEBUG:root:Plotting column dp 1074.0, distance=-1.5348410441508302, plotted=[np.float64(-43.0), np.float64(-1.0), np.float64(-20.0), np.float64(-16.0), np.float64(-55.0), np.float64(-2.0), np.float64(-46.0), np.float64(0.0), np.float64(-19.0), np.float64(-42.0), np.float64(-54.0), np.float64(-37.0), np.float64(-3.0)]
# DEBUG:root:Plotting column dp 1078.0, distance=-1.5072880597631308, plotted=[np.float64(-43.0), np.float64(-1.0), np.float64(-20.0), np.float64(-16.0), np.float64(-55.0), np.float64(-2.0), np.float64(-46.0), np.float64(0.0), np.float64(-19.0), np.float64(-42.0), np.float64(-54.0), np.float64(-37.0), np.float64(-3.0), np.float64(1.0)]
# DEBUG:root:Closest dp with surface level profile to 1076 is 1076.0
# INFO:root:Plotting 1 standpipes in figure, method=by_dp.
# DEBUG:root:length oc: 1
# DEBUG:root:oc position values: ['kruin']
# WARNING:root:Unknown method by_dp for plotting stand pipes. Nothing plotted.
# DEBUG:root:gmw worden geplot, aantal: 1
# INFO:root:Plotting 1 standpipes in figure, method=by_dp_marker.
# c:\data\python\cloned\geolookup\docs\examples\..\..\geolookup\functions.py:773: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# DEBUG:asyncio:Using selector: SelectSelector
# INFO:choreographer.browsers.chromium:Chromium init'ed with kwargs {}
# DEBUG:root:Looking for browser, skipping local? False
# DEBUG:root:Looking for at local chrome download path: C:\Users\HMEUW\.conda\envs\wk20260129\Lib\site-packages\choreographer\cli\browser_exe\chrome-win64\chrome.exe
# DEBUG:root:Local chrome not found at path: C:\Users\HMEUW\.conda\envs\wk20260129\Lib\site-packages\choreographer\cli\browser_exe\chrome-win64\chrome.exe.
# INFO:choreographer.browsers.chromium:Found chromium path: C:\Program Files\Google\Chrome\Application\chrome.exe
# INFO:choreographer.utils._tmpfile:Temp directory created: C:\Users\HMEUW\AppData\Local\Temp\tmpgl1ktxwr.
# INFO:choreographer.browser_async:Opening browser.
# INFO:choreographer.utils._tmpfile:Temp directory created: C:\Users\HMEUW\AppData\Local\Temp\tmpnj4uch7l.
# INFO:choreographer.browsers.chromium:Temporary directory at: C:\Users\HMEUW\AppData\Local\Temp\tmpnj4uch7l
# DEBUG:browser_proc:[INFO:components\enterprise\browser\controller\chrome_browser_cloud_management_controller.cc:206] No machine level policy manager exists.
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\external_pref_loader.cc:296] You are using an old-style extension deployment method (external_extensions.json), which will soon be deprecated. (see http://developer.chrome.com/docs/extensions/how-to/distribute/install-extensions)
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\external_registry_loader_win.cc:236] Error observing HKLM: Toegang geweigerd. (0x5)
# INFO:kaleido.kaleido:Conforming 1 to file:///C:/Users/HMEUW/AppData/Local/Temp/tmpgl1ktxwr/index.html
# INFO:kaleido.kaleido:Waiting on all navigates
# DEBUG:browser_proc:[WARNING:chrome\browser\extensions\forced_extensions\force_installed_metrics.cc:511] All forced extensions seem to be installed
# INFO:kaleido.kaleido:All navigates done, putting them all in queue.
# INFO:kaleido.kaleido:Getting tab from queue (has 1)
# INFO:kaleido.kaleido:Got 77AA
# INFO:kaleido._kaleido_tab:Processing profiel_rondom_dp1076__200m_tekening_Deltaversterking_bij_dp10733__270m.png
# INFO:kaleido._kaleido_tab:Sending big command for profiel_rondom_dp1076__200m_tekening_Deltaversterking_bij_dp10733__270m.png.
# INFO:kaleido._kaleido_tab:Sent big command for profiel_rondom_dp1076__200m_tekening_Deltaversterking_bij_dp10733__270m.png.
# INFO:kaleido.kaleido:Reloading tab 77AA before return.
# INFO:kaleido.kaleido:Putting tab 77AA back (queue size: 0).
# INFO:kaleido.kaleido:Waiting for all cleanups to finish.
# INFO:kaleido.kaleido:Exiting Kaleido
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.browser_async:Closing browser.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:choreographer.utils._tmpfile:TemporaryDirectory.cleanup() worked.
# INFO:choreographer.utils._tmpfile:shutil.rmtree worked.
# INFO:kaleido.kaleido:Cancelling tasks.
# INFO:kaleido.kaleido:Exiting Kaleido/Choreo

# %% [markdown]
# Verschuiving proberen

# %%
dp_fig = 736.5
dp_center = 736
fn = df_section.loc[df_section.dp == dp_fig, 'dsn_file_tif'].values[0]

print(fn)
from plotly.subplots import make_subplots
import plotly.io as pio

figure = make_subplots(
        rows=1,
        cols=1,
        horizontal_spacing=0.01,
    )

gl.plot_deltaversterking_background(figure, fn, dp=None, fig_row=1, fig_col=1, x_offset=-5)

gl.select_and_plot_surfacelevelprofile(dp_center, figure, df_profile, delta_dp=0, region='Os', fig_row=1, fig_col=1)

figure.update_xaxes(range=[-30, 20], row=1, col=1)

pio.write_html(figure, file=r'c:\temp\test.html', auto_open=True)
# Out:
# DEBUG:root:Adding Deltaversterking background from 78\doorsnedes\dsn9_flipped.tif to figure at row 1, col 1.
# DEBUG:root:Closest dp with surface level profile to 736 is 736.0
# N27-2_data\\deltaversterking\os0725-0778\doorsnedes\dsn9_flipped.tif

# %%
fn
# Out:
# 'N27-2_data\\\\deltaversterking\\os0725-0778\\doorsnedes\\dsn12_flipped.tif'

# %%
os.getcwd()
# Out:
# 'c:\\data\\python\\cloned\\geolookup\\docs\\examples'
